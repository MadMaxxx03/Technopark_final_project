# %% [markdown]
# # Глава 0. Общая идея использования KAN архитектуры для классификации

# %%
from kan import KAN
import matplotlib.pyplot as plt
from sklearn.datasets import make_moons
import torch
import numpy as np
import os
# Out:
# D:\Anaconda\lib\site-packages\pandas\core\computation\expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# D:\Anaconda\lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.2' currently installed).
#   from pandas.core import (

# %%
dataset = {}
train_input, train_label = make_moons(n_samples=1000, shuffle=True, noise=0.30, random_state=42)
test_input, test_label = make_moons(n_samples=1000, shuffle=True, noise=0.40, random_state=42)

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
print(device)

dtype = torch.get_default_dtype()
# Out:
# cuda:0

# %%
dataset['train_input'] = torch.from_numpy(train_input).type(dtype).to(device)
dataset['test_input'] = torch.from_numpy(test_input).type(dtype).to(device)
dataset['train_label'] = torch.from_numpy(train_label).type(torch.long).to(device)
dataset['test_label'] = torch.from_numpy(test_label).type(torch.long).to(device)

# %%
X = dataset['train_input']
y = dataset['train_label']
plt.scatter(X[:,0].cpu().detach().numpy(), X[:,1].cpu().detach().numpy(), c=y[:].cpu().detach().numpy())

# %%
model = KAN(width=[2,2], grid=3, k=3, seed=2024, device=device, auto_save=False)

def train_acc():
    correct = 0
    total = len(dataset["train_label"])
    
    outputs = model(dataset["train_input"])
    _, predicted = torch.max(outputs, 1)
    
    correct += (predicted == dataset["train_label"]).sum()
    accuracy = correct / total
    return accuracy
                            
def test_acc():
    correct = 0
    total = len(dataset["test_label"])
    
    outputs = model(dataset["test_input"])
    _, predicted = torch.max(outputs, 1)
    
    correct += (predicted == dataset["test_label"]).sum()
    accuracy = correct / total
    return accuracy

results = model.fit(dataset, 
                    opt="LBFGS", 
                    steps=200, 
                    metrics=(train_acc, test_acc), 
                    loss_fn=torch.nn.CrossEntropyLoss());
# Out:
# | train_loss: 4.50e-01 | test_loss: 6.30e-01 | reg: 3.30e+03 | : 100%|█| 200/200 [00:13<00:00, 15.35

# %%
lib = ['x','x^2','x^3','x^4','exp','log','sqrt','tanh','sin','abs']
model.auto_symbolic(lib=lib)
# Out:
# fixing (0,0,0) with sin, r2=0.9912105798721313, c=2
# fixing (0,0,1) with sin, r2=0.9911060929298401, c=2
# fixing (0,1,0) with sin, r2=0.9946809411048889, c=2
# fixing (0,1,1) with sin, r2=0.9956253170967102, c=2

# %%
formula1, formula2 = model.symbolic_formula()[0]

# %%
formula1
# Out:
# -1086.33972167969*sin(1.21127986907959*x_1 + 5.19015979766846) + 919.682800292969*sin(2.14159989356995*x_2 - 7.38032007217407) - 115.557456970215

# %%
formula2
# Out:
# -1075.08764648438*sin(1.22631990909576*x_1 + 5.18943977355957) + 905.316284179688*sin(2.17903995513916*x_2 + 5.18703985214233) - 118.918121337891

# %%
model = model.prune()
model.plot()
# Out:
# saving model version 0.1

# %%
def validate_model(model, X, y, device):
    correct = 0
    total = len(y)
    
    outputs = model(X)
    _, predicted = torch.max(outputs, 1)
    
    correct += (predicted == y).sum()
    accuracy = correct / total
    return accuracy

# %%
train_accuracy = validate_model(model, dataset["train_input"], dataset["train_label"] , device)
test_accuracy = validate_model(model, dataset["test_input"], dataset["test_label"] , device)
print(f"Train Accuracy: {train_accuracy}")
print(f"Test Accuracy: {test_accuracy}")
# Out:
# Train Accuracy: 0.7610000371932983
# Test Accuracy: 0.734000027179718

# %% [markdown]
# # Глава 1. Использование KAN как самостоятельной сети

# %% [markdown]
# ## 1.1. Использование архитектуры KAN без предварительной обработки изображений

# %%
from kan import KAN
import torch
import numpy as np
import os
from torchvision import transforms
from PIL import Image

# %%
transform = transforms.Compose([
    transforms.Resize((112, 112)),
    transforms.ToTensor(),
    transforms.Normalize(mean=(0.48145466, 0.4578275, 0.40821073), 
                         std=(0.26862954, 0.26130258, 0.27577711))
])

# %%
def shuffle_images(images, labels, filenames=None):
    indices = np.arange(len(labels))
    np.random.shuffle(indices)

    images = images[indices]
    labels = labels[indices]
    if filenames:
        filenames = filenames[indices]
    
    return images, labels, filenames

# %%
def make_dataset_for_kan(train_images, train_labels, test_images, test_labels):

    dataset = {}

    dataset['train_input'] = torch.from_numpy(train_images.cpu().numpy()).type(dtype).to(device)
    dataset['train_label'] = torch.from_numpy(train_labels).type(torch.long).to(device)

    dataset['test_input'] = torch.from_numpy(test_images.cpu().numpy()).type(dtype).to(device)
    dataset['test_label'] = torch.from_numpy(test_labels).type(torch.long).to(device)
    
    return dataset

# %%
import matplotlib.pyplot as plt

def plot_kan_results(results):

    train_loss = results['train_loss']
    test_loss = results['test_loss']

    plt.figure(figsize=(10, 6))
    plt.plot(range(len(train_loss)), train_loss, label='Train Loss', marker='o', linestyle='-', color='blue')
    plt.plot(range(len(test_loss)), test_loss, label='Test Loss', marker='s', linestyle='--', color='red')

    plt.title('KAN Architecture. Train/Test Loss', fontsize=16)
    plt.xlabel('Epochs', fontsize=14)
    plt.ylabel('Loss', fontsize=14)
    plt.legend(fontsize=12)
    plt.grid(True, linestyle='--', alpha=0.6)
    plt.xticks(fontsize=12)
    plt.yticks(fontsize=12)

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### 1.1.1. Smoking Dataset

# %%
device = "cuda:0" if torch.cuda.is_available() else "cpu"
train_path = './smokers_dataset/Training'
test_path = './smokers_dataset/Testing'
dtype = torch.get_default_dtype()

# %%
def process_images(image_dir:str, transforms=None):
    """
    Process smoking dataset from directory using transforms
    
    Args:
        image_dir (str): Путь к директории с исходными изображениями.

    Returns:
        - Список обработанных тензоров изображений.
        - Список меток для изображений.
        - Список с именами файлов
    """
    
    processed_images = []
    labels = []
    filenames = []
    
    for filename in os.listdir(image_dir):
        if filename.lower().endswith(".jpg"):
            image_path = os.path.join(image_dir, filename)
            
            image = Image.open(image_path).convert("RGB")
            
            label = 0 if "notsmoking" in filename else 1 if "smoking" in filename else None
            if label is not None:
                labels.append(label)
                filenames.append(filename)
            else:
                print(f"Не удалось определить метку для файла: {filename}")
            
            processed_image = transform(image)
            processed_images.append(processed_image.view(-1))
            
#             print(f"processed: {filename}, value {processed_image}")
    
    return torch.stack(processed_images), np.array(labels), np.array(filenames)

# %%
train_images, train_labels, train_filenames = process_images(train_path, transform)
test_images, test_labels, test_filenames = process_images(test_path, transform)

# %%
print(f"Train Images Size: {train_images.shape}")
print(f"Test Images Size: {test_images.shape}")
# Out:
# Train Images Size: torch.Size([716, 37632])
# Test Images Size: torch.Size([224, 37632])

# %%
indices = np.arange(len(train_labels))
np.random.shuffle(indices)

train_images = train_images[indices]
train_labels = train_labels[indices]
train_filenames = train_filenames[indices]

# %%
indices = np.arange(len(test_labels))
np.random.shuffle(indices)

test_images = test_images[indices]
test_labels = test_labels[indices]
test_filenames = test_filenames[indices]

# %%
answers = {filename : label for filename, label in zip(train_filenames, train_labels)}
answers
# Out:
# {'notsmoking_0312.jpg': 0,
#  'notsmoking_0416.jpg': 0,
#  'notsmoking_0303.jpg': 0,
#  'smoking_0314.jpg': 1,
#  'notsmoking_0064.jpg': 0,
#  'smoking_0543.jpg': 1,
#  'smoking_0354.jpg': 1,
#  'smoking_0251.jpg': 1,
#  'notsmoking_0030.jpg': 0,
#  'notsmoking_0204.jpg': 0,
#  'smoking_0427.jpg': 1,
#  'notsmoking_0051.jpg': 0,
#  'notsmoking_0489.jpg': 0,
#  'notsmoking_0003.jpg': 0,
#  'notsmoking_0295.jpg': 0,
#  'smoking_0523.jpg': 1,
#  'notsmoking_0331.jpg': 0,
#  'notsmoking_0148.jpg': 0,
#  'smoking_0363.jpg': 1,
#  'notsmoking_0126.jpg': 0,
#  'smoking_0450.jpg': 1,
#  'notsmoking_0456.jpg': 0,
#  'smoking_0421.jpg': 1,
#  'notsmoking_0499.jpg': 0,
#  'notsmoking_0082.jpg': 0,
#  'notsmoking_0361.jpg': 0,
#  'notsmoking_0080.jpg': 0,
#  'smoking_0510.jpg': 1,
#  'smoking_0065.jpg': 1,
#  'smoking_0082.jpg': 1,
#  'notsmoking_0292.jpg': 0,
#  'smoking_0455.jpg': 1,
#  'smoking_0393.jpg': 1,
#  'smoking_0057.jpg': 1,
#  'smoking_0341.jpg': 1,
#  'smoking_0179.jpg': 1,
#  'notsmoking_0458.jpg': 0,
#  'smoking_0324.jpg': 1,
#  'notsmoking_0102.jpg': 0,
#  'notsmoking_0520.jpg': 0,
#  'smoking_0130.jpg': 1,
#  'notsmoking_0271.jpg': 0,
#  'smoking_0171.jpg': 1,
#  'smoking_0263.jpg': 1,
#  'notsmoking_0111.jpg': 0,
#  'smoking_0483.jpg': 1,
#  'smoking_0250.jpg': 1,
#  'notsmoking_0552.jpg': 0,
#  'smoking_0512.jpg': 1,
#  'smoking_0266.jpg': 1,
#  'smoking_0493.jpg': 1,
#  'notsmoking_0189.jpg': 0,
#  'notsmoking_0451.jpg': 0,
#  'notsmoking_0112.jpg': 0,
#  'notsmoking_0527.jpg': 0,
#  'smoking_0532.jpg': 1,
#  'notsmoking_0101.jpg': 0,
#  'smoking_0548.jpg': 1,
#  'notsmoking_0343.jpg': 0,
#  'smoking_0416.jpg': 1,
#  'smoking_0004.jpg': 1,
#  'smoking_0364.jpg': 1,
#  'notsmoking_0332.jpg': 0,
#  'notsmoking_0483.jpg': 0,
#  'notsmoking_0103.jpg': 0,
#  'notsmoking_0199.jpg': 0,
#  'smoking_0126.jpg': 1,
#  'notsmoking_0287.jpg': 0,
#  'notsmoking_0325.jpg': 0,
#  'notsmoking_0484.jpg': 0,
#  'notsmoking_0046.jpg': 0,
#  'notsmoking_0242.jpg': 0,
#  'notsmoking_0349.jpg': 0,
#  'smoking_0044.jpg': 1,
#  'smoking_0356.jpg': 1,
#  'notsmoking_0436.jpg': 0,
#  'notsmoking_0020.jpg': 0,
#  'notsmoking_0384.jpg': 0,
#  'notsmoking_0181.jpg': 0,
#  'smoking_0164.jpg': 1,
#  'notsmoking_0375.jpg': 0,
#  'smoking_0401.jpg': 1,
#  'smoking_0235.jpg': 1,
#  'smoking_0095.jpg': 1,
#  'notsmoking_0056.jpg': 0,
#  'notsmoking_0323.jpg': 0,
#  'notsmoking_0300.jpg': 0,
#  'notsmoking_0387.jpg': 0,
#  'smoking_0502.jpg': 1,
#  'smoking_0475.jpg': 1,
#  'notsmoking_0418.jpg': 0,
#  'smoking_0315.jpg': 1,
#  'notsmoking_0262.jpg': 0,
#  'smoking_0219.jpg': 1,
#  'notsmoking_0055.jpg': 0,
#  'notsmoking_0021.jpg': 0,
#  'notsmoking_0168.jpg': 0,
#  'notsmoking_0352.jpg': 0,
#  'smoking_0180.jpg': 1,
#  'notsmoking_0072.jpg': 0,
#  'smoking_0125.jpg': 1,
#  'smoking_0208.jpg': 1,
#  'notsmoking_0266.jpg': 0,
#  'notsmoking_0121.jpg': 0,
#  'smoking_0140.jpg': 1,
#  'smoking_0323.jpg': 1,
#  'smoking_0535.jpg': 1,
#  'smoking_0181.jpg': 1,
#  'smoking_0402.jpg': 1,
#  'notsmoking_0164.jpg': 0,
#  'notsmoking_0276.jpg': 0,
#  'smoking_0408.jpg': 1,
#  'notsmoking_0560.jpg': 0,
#  'notsmoking_0480.jpg': 0,
#  'smoking_0092.jpg': 1,
#  'smoking_0101.jpg': 1,
#  'smoking_0187.jpg': 1,
#  'smoking_0344.jpg': 1,
#  'smoking_0348.jpg': 1,
#  'smoking_0207.jpg': 1,
#  'smoking_0459.jpg': 1,
#  'smoking_0183.jpg': 1,
#  'smoking_0094.jpg': 1,
#  'smoking_0214.jpg': 1,
#  'smoking_0327.jpg': 1,
#  'smoking_0410.jpg': 1,
#  'notsmoking_0379.jpg': 0,
#  'smoking_0152.jpg': 1,
#  'smoking_0478.jpg': 1,
#  'smoking_0019.jpg': 1,
#  'notsmoking_0288.jpg': 0,
#  'notsmoking_0077.jpg': 0,
#  'notsmoking_0394.jpg': 0,
#  'notsmoking_0117.jpg': 0,
#  'smoking_0212.jpg': 1,
#  'notsmoking_0240.jpg': 0,
#  'notsmoking_0322.jpg': 0,
#  'notsmoking_0229.jpg': 0,
#  'notsmoking_0169.jpg': 0,
#  'smoking_0099.jpg': 1,
#  'smoking_0226.jpg': 1,
#  'smoking_0143.jpg': 1,
#  'notsmoking_0397.jpg': 0,
#  'notsmoking_0059.jpg': 0,
#  'notsmoking_0411.jpg': 0,
#  'smoking_0370.jpg': 1,
#  'smoking_0318.jpg': 1,
#  'notsmoking_0316.jpg': 0,
#  'notsmoking_0097.jpg': 0,
#  'notsmoking_0109.jpg': 0,
#  'smoking_0466.jpg': 1,
#  'smoking_0012.jpg': 1,
#  'smoking_0538.jpg': 1,
#  'notsmoking_0305.jpg': 0,
#  'notsmoking_0507.jpg': 0,
#  'notsmoking_0135.jpg': 0,
#  'notsmoking_0364.jpg': 0,
#  'notsmoking_0347.jpg': 0,
#  'notsmoking_0555.jpg': 0,
#  'smoking_0053.jpg': 1,
#  'notsmoking_0452.jpg': 0,
#  'smoking_0015.jpg': 1,
#  'smoking_0371.jpg': 1,
#  'smoking_0274.jpg': 1,
#  'notsmoking_0250.jpg': 0,
#  'notsmoking_0087.jpg': 0,
#  'smoking_0395.jpg': 1,
#  'smoking_0273.jpg': 1,
#  'notsmoking_0447.jpg': 0,
#  'notsmoking_0450.jpg': 0,
#  'notsmoking_0439.jpg': 0,
#  'smoking_0267.jpg': 1,
#  'notsmoking_0463.jpg': 0,
#  'notsmoking_0195.jpg': 0,
#  'smoking_0530.jpg': 1,
#  'notsmoking_0495.jpg': 0,
#  'smoking_0191.jpg': 1,
#  'notsmoking_0093.jpg': 0,
#  'smoking_0133.jpg': 1,
#  'notsmoking_0098.jpg': 0,
#  'smoking_0011.jpg': 1,
#  'smoking_0309.jpg': 1,
#  'smoking_0376.jpg': 1,
#  'notsmoking_0280.jpg': 0,
#  'notsmoking_0356.jpg': 0,
#  'notsmoking_0094.jpg': 0,
#  'smoking_0245.jpg': 1,
#  'smoking_0121.jpg': 1,
#  'notsmoking_0005.jpg': 0,
#  'notsmoking_0143.jpg': 0,
#  'smoking_0225.jpg': 1,
#  'smoking_0022.jpg': 1,
#  'smoking_0473.jpg': 1,
#  'notsmoking_0485.jpg': 0,
#  'smoking_0021.jpg': 1,
#  'smoking_0296.jpg': 1,
#  'notsmoking_0308.jpg': 0,
#  'smoking_0501.jpg': 1,
#  'smoking_0360.jpg': 1,
#  'notsmoking_0400.jpg': 0,
#  'smoking_0010.jpg': 1,
#  'notsmoking_0320.jpg': 0,
#  'notsmoking_0293.jpg': 0,
#  'notsmoking_0025.jpg': 0,
#  'smoking_0470.jpg': 1,
#  'smoking_0497.jpg': 1,
#  'notsmoking_0002.jpg': 0,
#  'smoking_0560.jpg': 1,
#  'smoking_0013.jpg': 1,
#  'smoking_0078.jpg': 1,
#  'notsmoking_0342.jpg': 0,
#  'notsmoking_0260.jpg': 0,
#  'smoking_0252.jpg': 1,
#  'smoking_0396.jpg': 1,
#  'smoking_0448.jpg': 1,
#  'smoking_0387.jpg': 1,
#  'smoking_0155.jpg': 1,
#  'smoking_0383.jpg': 1,
#  'notsmoking_0090.jpg': 0,
#  'smoking_0306.jpg': 1,
#  'notsmoking_0550.jpg': 0,
#  'notsmoking_0206.jpg': 0,
#  'notsmoking_0070.jpg': 0,
#  'notsmoking_0445.jpg': 0,
#  'notsmoking_0459.jpg': 0,
#  'notsmoking_0513.jpg': 0,
#  'smoking_0431.jpg': 1,
#  'notsmoking_0086.jpg': 0,
#  'smoking_0034.jpg': 1,
#  'smoking_0283.jpg': 1,
#  'notsmoking_0339.jpg': 0,
#  'smoking_0526.jpg': 1,
#  'smoking_0064.jpg': 1,
#  'notsmoking_0253.jpg': 0,
#  'smoking_0112.jpg': 1,
#  'notsmoking_0008.jpg': 0,
#  'smoking_0270.jpg': 1,
#  'smoking_0029.jpg': 1,
#  'notsmoking_0430.jpg': 0,
#  'notsmoking_0425.jpg': 0,
#  'smoking_0420.jpg': 1,
#  'smoking_0462.jpg': 1,
#  'notsmoking_0273.jpg': 0,
#  'smoking_0059.jpg': 1,
#  'notsmoking_0123.jpg': 0,
#  'notsmoking_0362.jpg': 0,
#  'notsmoking_0454.jpg': 0,
#  'notsmoking_0173.jpg': 0,
#  'smoking_0269.jpg': 1,
#  'notsmoking_0386.jpg': 0,
#  'notsmoking_0412.jpg': 0,
#  'notsmoking_0156.jpg': 0,
#  'smoking_0257.jpg': 1,
#  'notsmoking_0089.jpg': 0,
#  'smoking_0394.jpg': 1,
#  'smoking_0537.jpg': 1,
#  'smoking_0492.jpg': 1,
#  'smoking_0002.jpg': 1,
#  'smoking_0023.jpg': 1,
#  'notsmoking_0040.jpg': 0,
#  'smoking_0480.jpg': 1,
#  'smoking_0107.jpg': 1,
#  'smoking_0149.jpg': 1,
#  'notsmoking_0274.jpg': 0,
#  'notsmoking_0031.jpg': 0,
#  'smoking_0317.jpg': 1,
#  'notsmoking_0136.jpg': 0,
#  'notsmoking_0326.jpg': 0,
#  'smoking_0085.jpg': 1,
#  'smoking_0518.jpg': 1,
#  'notsmoking_0544.jpg': 0,
#  'notsmoking_0264.jpg': 0,
#  'notsmoking_0179.jpg': 0,
#  'smoking_0357.jpg': 1,
#  'smoking_0343.jpg': 1,
#  'notsmoking_0210.jpg': 0,
#  'notsmoking_0391.jpg': 0,
#  'notsmoking_0152.jpg': 0,
#  'smoking_0284.jpg': 1,
#  'smoking_0440.jpg': 1,
#  'smoking_0186.jpg': 1,
#  'smoking_0312.jpg': 1,
#  'smoking_0419.jpg': 1,
#  'smoking_0289.jpg': 1,
#  'notsmoking_0471.jpg': 0,
#  'smoking_0016.jpg': 1,
#  'smoking_0066.jpg': 1,
#  'notsmoking_0392.jpg': 0,
#  'smoking_0084.jpg': 1,
#  'smoking_0439.jpg': 1,
#  'smoking_0414.jpg': 1,
#  'smoking_0200.jpg': 1,
#  'notsmoking_0201.jpg': 0,
#  'notsmoking_0076.jpg': 0,
#  'smoking_0271.jpg': 1,
#  'smoking_0159.jpg': 1,
#  'notsmoking_0314.jpg': 0,
#  'smoking_0046.jpg': 1,
#  'smoking_0380.jpg': 1,
#  'smoking_0203.jpg': 1,
#  'smoking_0498.jpg': 1,
#  'smoking_0272.jpg': 1,
#  'notsmoking_0546.jpg': 0,
#  'smoking_0389.jpg': 1,
#  'smoking_0435.jpg': 1,
#  'notsmoking_0110.jpg': 0,
#  'smoking_0128.jpg': 1,
#  'notsmoking_0346.jpg': 0,
#  'smoking_0005.jpg': 1,
#  'notsmoking_0183.jpg': 0,
#  'smoking_0118.jpg': 1,
#  'smoking_0524.jpg': 1,
#  'notsmoking_0419.jpg': 0,
#  'notsmoking_0286.jpg': 0,
#  'smoking_0295.jpg': 1,
#  'notsmoking_0257.jpg': 0,
#  'notsmoking_0476.jpg': 0,
#  'notsmoking_0193.jpg': 0,
#  'smoking_0463.jpg': 1,
#  'smoking_0072.jpg': 1,
#  'smoking_0249.jpg': 1,
#  'notsmoking_0506.jpg': 0,
#  'notsmoking_0359.jpg': 0,
#  'smoking_0086.jpg': 1,
#  'notsmoking_0341.jpg': 0,
#  'smoking_0147.jpg': 1,
#  'notsmoking_0176.jpg': 0,
#  'notsmoking_0548.jpg': 0,
#  'smoking_0188.jpg': 1,
#  'smoking_0156.jpg': 1,
#  'smoking_0256.jpg': 1,
#  'notsmoking_0464.jpg': 0,
#  'smoking_0174.jpg': 1,
#  'notsmoking_0099.jpg': 0,
#  'notsmoking_0282.jpg': 0,
#  'notsmoking_0302.jpg': 0,
#  'smoking_0230.jpg': 1,
#  'smoking_0476.jpg': 1,
#  'notsmoking_0540.jpg': 0,
#  'notsmoking_0142.jpg': 0,
#  'smoking_0468.jpg': 1,
#  'notsmoking_0475.jpg': 0,
#  'notsmoking_0486.jpg': 0,
#  'notsmoking_0536.jpg': 0,
#  'smoking_0001.jpg': 1,
#  'smoking_0461.jpg': 1,
#  'smoking_0458.jpg': 1,
#  'smoking_0194.jpg': 1,
#  'notsmoking_0324.jpg': 0,
#  'notsmoking_0330.jpg': 0,
#  'smoking_0316.jpg': 1,
#  'smoking_0169.jpg': 1,
#  'notsmoking_0245.jpg': 0,
#  'smoking_0202.jpg': 1,
#  'notsmoking_0129.jpg': 0,
#  'smoking_0338.jpg': 1,
#  'notsmoking_0453.jpg': 0,
#  'smoking_0142.jpg': 1,
#  'smoking_0552.jpg': 1,
#  'smoking_0136.jpg': 1,
#  'notsmoking_0429.jpg': 0,
#  'notsmoking_0188.jpg': 0,
#  'smoking_0028.jpg': 1,
#  'smoking_0504.jpg': 1,
#  'smoking_0488.jpg': 1,
#  'notsmoking_0074.jpg': 0,
#  'smoking_0138.jpg': 1,
#  'smoking_0054.jpg': 1,
#  'smoking_0025.jpg': 1,
#  'notsmoking_0551.jpg': 0,
#  'notsmoking_0054.jpg': 0,
#  'smoking_0359.jpg': 1,
#  'notsmoking_0468.jpg': 0,
#  'smoking_0098.jpg': 1,
#  'smoking_0003.jpg': 1,
#  'notsmoking_0254.jpg': 0,
#  'notsmoking_0497.jpg': 0,
#  'notsmoking_0234.jpg': 0,
#  'smoking_0114.jpg': 1,
#  'smoking_0262.jpg': 1,
#  'notsmoking_0415.jpg': 0,
#  'smoking_0432.jpg': 1,
#  'smoking_0299.jpg': 1,
#  'smoking_0392.jpg': 1,
#  'smoking_0517.jpg': 1,
#  'notsmoking_0027.jpg': 0,
#  'smoking_0123.jpg': 1,
#  'smoking_0531.jpg': 1,
#  'smoking_0353.jpg': 1,
#  'notsmoking_0160.jpg': 0,
#  'smoking_0293.jpg': 1,
#  'smoking_0438.jpg': 1,
#  'smoking_0048.jpg': 1,
#  'notsmoking_0015.jpg': 0,
#  'smoking_0430.jpg': 1,
#  'notsmoking_0421.jpg': 0,
#  'notsmoking_0221.jpg': 0,
#  'smoking_0151.jpg': 1,
#  'notsmoking_0423.jpg': 0,
#  'notsmoking_0545.jpg': 0,
#  'notsmoking_0479.jpg': 0,
#  'smoking_0499.jpg': 1,
#  'notsmoking_0461.jpg': 0,
#  'notsmoking_0526.jpg': 0,
#  'notsmoking_0033.jpg': 0,
#  'notsmoking_0023.jpg': 0,
#  'smoking_0336.jpg': 1,
#  'smoking_0131.jpg': 1,
#  'smoking_0158.jpg': 1,
#  'smoking_0509.jpg': 1,
#  'smoking_0276.jpg': 1,
#  'smoking_0335.jpg': 1,
#  'smoking_0017.jpg': 1,
#  'smoking_0195.jpg': 1,
#  'smoking_0288.jpg': 1,
#  'notsmoking_0128.jpg': 0,
#  'notsmoking_0066.jpg': 0,
#  'notsmoking_0261.jpg': 0,
#  'smoking_0495.jpg': 1,
#  'smoking_0042.jpg': 1,
#  'smoking_0166.jpg': 1,
#  'notsmoking_0512.jpg': 0,
#  'notsmoking_0505.jpg': 0,
#  'smoking_0265.jpg': 1,
#  'smoking_0355.jpg': 1,
#  'smoking_0173.jpg': 1,
#  'smoking_0310.jpg': 1,
#  'notsmoking_0381.jpg': 0,
#  'notsmoking_0472.jpg': 0,
#  'notsmoking_0083.jpg': 0,
#  'smoking_0449.jpg': 1,
#  'notsmoking_0161.jpg': 0,
#  'notsmoking_0516.jpg': 0,
#  'notsmoking_0337.jpg': 0,
#  'notsmoking_0203.jpg': 0,
#  'notsmoking_0227.jpg': 0,
#  'notsmoking_0366.jpg': 0,
#  'notsmoking_0297.jpg': 0,
#  'smoking_0039.jpg': 1,
#  'smoking_0465.jpg': 1,
#  'notsmoking_0157.jpg': 0,
#  'smoking_0135.jpg': 1,
#  'notsmoking_0174.jpg': 0,
#  'smoking_0204.jpg': 1,
#  'smoking_0433.jpg': 1,
#  'notsmoking_0390.jpg': 0,
#  'smoking_0077.jpg': 1,
#  'notsmoking_0317.jpg': 0,
#  'notsmoking_0186.jpg': 0,
#  'notsmoking_0139.jpg': 0,
#  'notsmoking_0318.jpg': 0,
#  'smoking_0146.jpg': 1,
#  'smoking_0062.jpg': 1,
#  'smoking_0286.jpg': 1,
#  'smoking_0489.jpg': 1,
#  'smoking_0550.jpg': 1,
#  'notsmoking_0404.jpg': 0,
#  'smoking_0505.jpg': 1,
#  'smoking_0228.jpg': 1,
#  'notsmoking_0042.jpg': 0,
#  'notsmoking_0220.jpg': 0,
#  'notsmoking_0401.jpg': 0,
#  'smoking_0008.jpg': 1,
#  'notsmoking_0371.jpg': 0,
#  'smoking_0168.jpg': 1,
#  'smoking_0124.jpg': 1,
#  'notsmoking_0039.jpg': 0,
#  'notsmoking_0045.jpg': 0,
#  'smoking_0035.jpg': 1,
#  'smoking_0007.jpg': 1,
#  'notsmoking_0395.jpg': 0,
#  'notsmoking_0009.jpg': 0,
#  'smoking_0215.jpg': 1,
#  'smoking_0090.jpg': 1,
#  'notsmoking_0150.jpg': 0,
#  'smoking_0106.jpg': 1,
#  'smoking_0184.jpg': 1,
#  'notsmoking_0241.jpg': 0,
#  'smoking_0503.jpg': 1,
#  'notsmoking_0265.jpg': 0,
#  'smoking_0319.jpg': 1,
#  'notsmoking_0132.jpg': 0,
#  'smoking_0258.jpg': 1,
#  'smoking_0109.jpg': 1,
#  'notsmoking_0267.jpg': 0,
#  'notsmoking_0443.jpg': 0,
#  'smoking_0549.jpg': 1,
#  'smoking_0141.jpg': 1,
#  'smoking_0382.jpg': 1,
#  'smoking_0134.jpg': 1,
#  'smoking_0557.jpg': 1,
#  'notsmoking_0309.jpg': 0,
#  'notsmoking_0559.jpg': 0,
#  'notsmoking_0350.jpg': 0,
#  'notsmoking_0191.jpg': 0,
#  'notsmoking_0061.jpg': 0,
#  'smoking_0209.jpg': 1,
#  'notsmoking_0408.jpg': 0,
#  'notsmoking_0125.jpg': 0,
#  'smoking_0242.jpg': 1,
#  'notsmoking_0435.jpg': 0,
#  'notsmoking_0208.jpg': 0,
#  'smoking_0442.jpg': 1,
#  'notsmoking_0247.jpg': 0,
#  'notsmoking_0226.jpg': 0,
#  'smoking_0027.jpg': 1,
#  'smoking_0294.jpg': 1,
#  'smoking_0087.jpg': 1,
#  'notsmoking_0236.jpg': 0,
#  'notsmoking_0249.jpg': 0,
#  'smoking_0041.jpg': 1,
#  'notsmoking_0001.jpg': 0,
#  'notsmoking_0138.jpg': 0,
#  'smoking_0110.jpg': 1,
#  'smoking_0229.jpg': 1,
#  'smoking_0259.jpg': 1,
#  'smoking_0554.jpg': 1,
#  'notsmoking_0011.jpg': 0,
#  'notsmoking_0149.jpg': 0,
#  'notsmoking_0211.jpg': 0,
#  'notsmoking_0118.jpg': 0,
#  'smoking_0162.jpg': 1,
#  'notsmoking_0214.jpg': 0,
#  'smoking_0418.jpg': 1,
#  'notsmoking_0427.jpg': 0,
#  'notsmoking_0170.jpg': 0,
#  'notsmoking_0178.jpg': 0,
#  'notsmoking_0285.jpg': 0,
#  'smoking_0307.jpg': 1,
#  'notsmoking_0019.jpg': 0,
#  'smoking_0075.jpg': 1,
#  'notsmoking_0215.jpg': 0,
#  'notsmoking_0473.jpg': 0,
#  'notsmoking_0068.jpg': 0,
#  'smoking_0452.jpg': 1,
#  'smoking_0049.jpg': 1,
#  'smoking_0428.jpg': 1,
#  'smoking_0328.jpg': 1,
#  'smoking_0508.jpg': 1,
#  'notsmoking_0466.jpg': 0,
#  'smoking_0055.jpg': 1,
#  'smoking_0386.jpg': 1,
#  'smoking_0213.jpg': 1,
#  'smoking_0253.jpg': 1,
#  'smoking_0239.jpg': 1,
#  'notsmoking_0038.jpg': 0,
#  'smoking_0220.jpg': 1,
#  'smoking_0115.jpg': 1,
#  'notsmoking_0389.jpg': 0,
#  'smoking_0275.jpg': 1,
#  'notsmoking_0028.jpg': 0,
#  'notsmoking_0496.jpg': 0,
#  'notsmoking_0010.jpg': 0,
#  'notsmoking_0304.jpg': 0,
#  'smoking_0104.jpg': 1,
#  'smoking_0302.jpg': 1,
#  'smoking_0232.jpg': 1,
#  'smoking_0032.jpg': 1,
#  'notsmoking_0146.jpg': 0,
#  'notsmoking_0232.jpg': 0,
#  'notsmoking_0407.jpg': 0,
#  'smoking_0108.jpg': 1,
#  'smoking_0365.jpg': 1,
#  'notsmoking_0037.jpg': 0,
#  'notsmoking_0065.jpg': 0,
#  'smoking_0238.jpg': 1,
#  'notsmoking_0413.jpg': 0,
#  'smoking_0347.jpg': 1,
#  'notsmoking_0162.jpg': 0,
#  'smoking_0097.jpg': 1,
#  'smoking_0117.jpg': 1,
#  'notsmoking_0380.jpg': 0,
#  'notsmoking_0372.jpg': 0,
#  'smoking_0491.jpg': 1,
#  'smoking_0014.jpg': 1,
#  'notsmoking_0007.jpg': 0,
#  'notsmoking_0541.jpg': 0,
#  'notsmoking_0013.jpg': 0,
#  'smoking_0539.jpg': 1,
#  'smoking_0367.jpg': 1,
#  'smoking_0103.jpg': 1,
#  'notsmoking_0376.jpg': 0,
#  'notsmoking_0448.jpg': 0,
#  'smoking_0415.jpg': 1,
#  'smoking_0331.jpg': 1,
#  'notsmoking_0277.jpg': 0,
#  'smoking_0167.jpg': 1,
#  'smoking_0422.jpg': 1,
#  'smoking_0313.jpg': 1,
#  'notsmoking_0119.jpg': 0,
#  'notsmoking_0367.jpg': 0,
#  'notsmoking_0434.jpg': 0,
#  'notsmoking_0187.jpg': 0,
#  'smoking_0079.jpg': 1,
#  'notsmoking_0511.jpg': 0,
#  'notsmoking_0196.jpg': 0,
#  'notsmoking_0225.jpg': 0,
#  'smoking_0290.jpg': 1,
#  'smoking_0236.jpg': 1,
#  'smoking_0500.jpg': 1,
#  'smoking_0485.jpg': 1,
#  'smoking_0434.jpg': 1,
#  'smoking_0231.jpg': 1,
#  'smoking_0337.jpg': 1,
#  'notsmoking_0279.jpg': 0,
#  'notsmoking_0088.jpg': 0,
#  'notsmoking_0524.jpg': 0,
#  'notsmoking_0197.jpg': 0,
#  'notsmoking_0424.jpg': 0,
#  'smoking_0404.jpg': 1,
#  'smoking_0165.jpg': 1,
#  'notsmoking_0296.jpg': 0,
#  'notsmoking_0166.jpg': 0,
#  'smoking_0366.jpg': 1,
#  'smoking_0358.jpg': 1,
#  'notsmoking_0355.jpg': 0,
#  'smoking_0456.jpg': 1,
#  'smoking_0198.jpg': 1,
#  'smoking_0221.jpg': 1,
#  'smoking_0091.jpg': 1,
#  'notsmoking_0047.jpg': 0,
#  'notsmoking_0243.jpg': 0,
#  'notsmoking_0144.jpg': 0,
#  'notsmoking_0335.jpg': 0,
#  'notsmoking_0537.jpg': 0,
#  'smoking_0285.jpg': 1,
#  'notsmoking_0256.jpg': 0,
#  'smoking_0243.jpg': 1,
#  'notsmoking_0290.jpg': 0,
#  'notsmoking_0022.jpg': 0,
#  'smoking_0333.jpg': 1,
#  'smoking_0201.jpg': 1,
#  'notsmoking_0402.jpg': 0,
#  'notsmoking_0470.jpg': 0,
#  'notsmoking_0131.jpg': 0,
#  'smoking_0373.jpg': 1,
#  'smoking_0444.jpg': 1,
#  'smoking_0248.jpg': 1,
#  'smoking_0137.jpg': 1,
#  'smoking_0120.jpg': 1,
#  'notsmoking_0231.jpg': 0,
#  'notsmoking_0556.jpg': 0,
#  'smoking_0216.jpg': 1,
#  'notsmoking_0079.jpg': 0,
#  'notsmoking_0050.jpg': 0,
#  'notsmoking_0370.jpg': 0,
#  'notsmoking_0224.jpg': 0,
#  'notsmoking_0311.jpg': 0,
#  'notsmoking_0431.jpg': 0,
#  'notsmoking_0175.jpg': 0,
#  'smoking_0052.jpg': 1,
#  'notsmoking_0405.jpg': 0,
#  'notsmoking_0492.jpg': 0,
#  'notsmoking_0060.jpg': 0,
#  'notsmoking_0270.jpg': 0,
#  'smoking_0388.jpg': 1,
#  'notsmoking_0491.jpg': 0,
#  'smoking_0193.jpg': 1,
#  'smoking_0247.jpg': 1,
#  'notsmoking_0438.jpg': 0,
#  'notsmoking_0340.jpg': 0,
#  'notsmoking_0334.jpg': 0,
#  'smoking_0223.jpg': 1,
#  'notsmoking_0016.jpg': 0,
#  'smoking_0278.jpg': 1,
#  'smoking_0175.jpg': 1,
#  'smoking_0304.jpg': 1,
#  'smoking_0399.jpg': 1,
#  'notsmoking_0244.jpg': 0,
#  'notsmoking_0237.jpg': 0,
#  'notsmoking_0441.jpg': 0,
#  'notsmoking_0353.jpg': 0,
#  'notsmoking_0365.jpg': 0,
#  'smoking_0384.jpg': 1,
#  'notsmoking_0348.jpg': 0,
#  'smoking_0116.jpg': 1,
#  'notsmoking_0184.jpg': 0,
#  'smoking_0326.jpg': 1,
#  'smoking_0379.jpg': 1,
#  'smoking_0080.jpg': 1,
#  'notsmoking_0230.jpg': 0,
#  'notsmoking_0503.jpg': 0,
#  'smoking_0305.jpg': 1,
#  'smoking_0058.jpg': 1,
#  'smoking_0297.jpg': 1,
#  'notsmoking_0396.jpg': 0,
#  'notsmoking_0035.jpg': 0,
#  'smoking_0350.jpg': 1,
#  'smoking_0544.jpg': 1,
#  'notsmoking_0200.jpg': 0,
#  'smoking_0227.jpg': 1,
#  'notsmoking_0043.jpg': 0,
#  'notsmoking_0363.jpg': 0,
#  'notsmoking_0474.jpg': 0,
#  'smoking_0233.jpg': 1,
#  'smoking_0405.jpg': 1,
#  'notsmoking_0067.jpg': 0,
#  'notsmoking_0012.jpg': 0,
#  'smoking_0178.jpg': 1,
#  'notsmoking_0490.jpg': 0,
#  'notsmoking_0269.jpg': 0,
#  'smoking_0453.jpg': 1,
#  'notsmoking_0154.jpg': 0,
#  'notsmoking_0113.jpg': 0,
#  'notsmoking_0218.jpg': 0,
#  'notsmoking_0219.jpg': 0,
#  'smoking_0148.jpg': 1,
#  'smoking_0529.jpg': 1,
#  'smoking_0037.jpg': 1,
#  'notsmoking_0523.jpg': 0,
#  'notsmoking_0444.jpg': 0,
#  'notsmoking_0106.jpg': 0,
#  'notsmoking_0383.jpg': 0,
#  'notsmoking_0127.jpg': 0,
#  'notsmoking_0510.jpg': 0,
#  'notsmoking_0299.jpg': 0}

# %%
dataset = {}

dataset['train_input'] = torch.from_numpy(train_images.cpu().numpy()).type(dtype).to(device)
dataset['train_label'] = torch.from_numpy(train_labels).type(torch.long).to(device)

dataset['test_input'] = torch.from_numpy(test_images.cpu().numpy()).type(dtype).to(device)
dataset['test_label'] = torch.from_numpy(test_labels).type(torch.long).to(device)

# %%
train_images.shape[1] // 2
# Out:
# 18816

# %%
def train_acc():
    correct = 0
    total = len(dataset["train_label"])
    
    outputs = model(dataset["train_input"])
    _, predicted = torch.max(outputs, 1)
    
    correct += (predicted == dataset["train_label"]).sum()
    accuracy = correct / total
    
    return accuracy
                            
def test_acc():
    correct = 0
    total = len(dataset["test_label"])
    
    outputs = model(dataset["test_input"])
    _, predicted = torch.max(outputs, 1)
    
    correct += (predicted == dataset["test_label"]).sum()
    accuracy = correct / total
    return accuracy

# %%
# %%time
model = KAN(width=[train_images.shape[1], 2], 
            grid=5, 
            k=3, 
            seed=42, 
            device=device, 
            auto_save=True, 
            ckpt_path='./KAN_model')

results = model.fit(dataset, 
                    opt="LBFGS", 
                    steps=50,  
                    loss_fn=torch.nn.CrossEntropyLoss(), 
                    lamb=0.02, batch=64, lr=1e-4)
# Out:
# checkpoint directory created: ./KAN_model
# saving model version 0.0
# | train_loss: 6.56e-01 | test_loss: 7.41e-01 | reg: 2.35e+01 | : 100%|█| 50/50 [00:58<00:00,  1.17s/
# saving model version 0.1
# Wall time: 1min 13s

# %%
import matplotlib.pyplot as plt

train_loss = results['train_loss']
test_loss = results['test_loss']

plt.figure(figsize=(10, 6))
plt.plot(range(len(train_loss)), train_loss, label='Train Loss', marker='o', linestyle='-', color='blue')
plt.plot(range(len(test_loss)), test_loss, label='Test Loss', marker='s', linestyle='--', color='red')

plt.title('KAN Architecture. Train/Test Loss', fontsize=16)
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Loss', fontsize=14)
plt.legend(fontsize=12)
plt.grid(True, linestyle='--', alpha=0.6)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

plt.tight_layout()
plt.show()

# %%
def validate_kan_model(model, X, y):
    correct = 0
    total = len(y)
    
    outputs = model(X)
    _, predicted = torch.max(outputs, 1)
    
    correct += (predicted == y).sum()
    accuracy = correct / total
    return accuracy

# %%
# %%time

train_accuracy = validate_model(model, dataset["train_input"], dataset["train_label"])
test_accuracy = validate_model(model, dataset["test_input"], dataset["test_label"])

print(f"Train Accuracy: {train_accuracy}")
print(f"Test Accuracy: {test_accuracy}")
# Out:
# Train Accuracy: 0.7402234673500061
# Test Accuracy: 0.7008928656578064
# Wall time: 51.3 s

# %%
# %%time
# Using MLP

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset

class NeuralNetwork(nn.Module):
    def __init__(self, input_size, hidden_sizes, output_size):
        super(NeuralNetwork, self).__init__()
        layers = []
        previous_size = input_size
        for hidden_size in hidden_sizes:
            layers.append(nn.Linear(previous_size, hidden_size))
            layers.append(nn.ReLU())  # Функция активации
            previous_size = hidden_size
        layers.append(nn.Linear(previous_size, output_size))  # Выходной слой
        
        
        self.network = nn.Sequential(*layers)
    
    def forward(self, x):
        return self.network(x)

input_size = train_images.shape[1]
hidden_sizes = [train_images.shape[1] // 4, train_images.shape[1] // 16]
output_size = 2
batch_size = 64
epochs = 15

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

smoking_dataset = TensorDataset(dataset["train_input"].to(device), 
                                torch.tensor(dataset["train_label"]).to(device, dtype=torch.long)
)

dataloader = DataLoader(smoking_dataset, batch_size=batch_size, shuffle=True)

model = NeuralNetwork(input_size, hidden_sizes, output_size).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=2e-7)

train_mlp_loss = []

model.train()
for epoch in range(epochs):
    total_loss = 0.0
    for inputs, labels in dataloader:
        optimizer.zero_grad()

        outputs = model(inputs)

        loss = criterion(outputs, labels)

        loss.backward()
        optimizer.step()

        total_loss += loss.item()

    print(f"Epoch {epoch + 1}/{epochs}, Loss: {total_loss / len(dataloader):.4f}")
    train_mlp_loss.append(total_loss / len(dataloader))
    
    print("Training complete.")


def validate_model(model, dataloader, device):
    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for inputs, labels in dataloader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    accuracy = correct / total
    return accuracy

test_dataset = TensorDataset(dataset["test_input"].to(device), 
                             torch.tensor(dataset["test_label"]).to(device, dtype=torch.long))
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

train_accuracy = validate_model(model, dataloader, device)
test_accuracy = validate_model(model, test_dataloader, device)
print(f"Train Accuracy: {train_accuracy}")
print(f"Test Accuracy: {test_accuracy}")

plt.figure(figsize=(10, 6))
plt.plot(range(len(train_mlp_loss)), train_mlp_loss, label='Train Loss', marker='o', linestyle='-', color='blue')

plt.title('MLP Architecture. Train Loss', fontsize=16)
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Loss', fontsize=14)
plt.legend(fontsize=12)
plt.grid(True, linestyle='--', alpha=0.6)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

plt.tight_layout()
plt.show()
# Out:
# <timed exec>:34: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# Epoch 1/15, Loss: 0.6304
# Training complete.
# Epoch 2/15, Loss: 0.5752
# Training complete.
# Epoch 3/15, Loss: 0.5388
# Training complete.
# Epoch 4/15, Loss: 0.5402
# Training complete.
# Epoch 5/15, Loss: 0.5250
# Training complete.
# Epoch 6/15, Loss: 0.4995
# Training complete.
# Epoch 7/15, Loss: 0.5056
# Training complete.
# Epoch 8/15, Loss: 0.4909
# Training complete.
# Epoch 9/15, Loss: 0.4985
# Training complete.
# Epoch 10/15, Loss: 0.4895
# Training complete.
# Epoch 11/15, Loss: 0.4698
# Training complete.
# Epoch 12/15, Loss: 0.4605
# Training complete.
# Epoch 13/15, Loss: 0.4774
# Training complete.
# Epoch 14/15, Loss: 0.4648
# Training complete.
# Epoch 15/15, Loss: 0.4679
# Training complete.
# <timed exec>:81: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# Train Accuracy: 0.8002793296089385
# Test Accuracy: 0.7276785714285714
# Wall time: 27 s

# %% [markdown]
# Промежуточный вывод: получили одинаковое качество. Общее время работы для KAN архитектуры: ~120sec. Общее время для MLP: ~25sec

# %% [markdown]
# ## 1.2. Использование архитектуры KAN c предварительной обработкой изображений

# %% [markdown]
# ## 1.2.1 ResNet50 | Smoking Dataset

# %%
import torch
from torchvision import models, transforms
from PIL import Image

resnet = models.resnet50(pretrained=True)
model_embbed = torch.nn.Sequential(*(list(resnet.children())[:-1]))
model_embbed.eval()

image = Image.open("./images/smoking_0125.jpg").convert("RGB")
image
# Out:
# <PIL.Image.Image image mode=RGB size=250x250>

# %%
transform = transforms.Compose([
    transforms.Resize((224, 224)), 
    transforms.ToTensor(),          
    transforms.Normalize(          
        mean=[0.485, 0.456, 0.406], 
        std=[0.229, 0.224, 0.225]
    ),
])

input_tensor = transform(image).unsqueeze(0)

with torch.no_grad():
    embedding = model_embbed(input_tensor).squeeze()

# %%
device = "cuda:0" if torch.cuda.is_available() else "cpu"
train_path = './smokers_dataset/Training'
test_path = './smokers_dataset/Testing'
dtype = torch.get_default_dtype()

# %%
def process_images(image_dir:str, model_embbed, transform=None):
    """
    Process smoking dataset from directory using transforms
    
    Args:
        image_dir (str): Путь к директории с исходными изображениями.

    Returns:
        - Список обработанных тензоров изображений.
        - Список меток для изображений.
        - Список с именами файлов
    """
    
    processed_images = []
    labels = []
    filenames = []
    
    for filename in os.listdir(image_dir):
        if filename.lower().endswith(".jpg"):
            image_path = os.path.join(image_dir, filename)
            
            image = Image.open(image_path).convert("RGB")
            
            label = 0 if "notsmoking" in filename else 1 if "smoking" in filename else None
            if label is not None:
                labels.append(label)
                filenames.append(filename)
            else:
                print(f"Не удалось определить метку для файла: {filename}")
            
            processed_image = transform(image).unsqueeze(0)
            with torch.no_grad():
                embedding = model_embbed(processed_image).squeeze()
                processed_images.append(embedding)
            
#             print(f"processed: {filename}, value {processed_image}")
    
    return torch.stack(processed_images), np.array(labels), np.array(filenames)

# %%
train_images, train_labels, train_filenames = process_images(train_path, model_embbed, transform)
test_images, test_labels, test_filenames = process_images(test_path, model_embbed, transform)

# %%
print(f"Train Images Size: {train_images.shape}")
print(f"Test Images Size: {test_images.shape}")
# Out:
# Train Images Size: torch.Size([716, 2048])
# Test Images Size: torch.Size([224, 2048])

# %%
train_images, train_labels, train_filenames = shuffle_images(train_images, train_labels, train_filenames)
test_images, test_labels, test_filenames = shuffle_images(test_images, test_labels, test_filenames)

dataset = make_dataset_for_kan(train_images, train_labels, test_images, test_labels)

# %%
# %%time
model = KAN(width=[train_images.shape[1], 2], 
            grid=5, 
            k=3, 
            seed=42, 
            device=device, 
            auto_save=True, 
            ckpt_path='./KAN_model')

results = model.fit(dataset, 
                    opt="LBFGS", 
                    steps=50,  
                    loss_fn=torch.nn.CrossEntropyLoss(), 
                    lamb=0.02, batch=64, lr=1e-4)
# Out:
# checkpoint directory created: ./KAN_model
# saving model version 0.0
# | train_loss: 6.04e-01 | test_loss: 5.11e-01 | reg: 1.59e+01 | : 100%|█| 50/50 [00:09<00:00,  5.24it
# saving model version 0.1
# Wall time: 9.91 s

# %%
plot_kan_results(results)

# %%
# %%time

train_accuracy = validate_kan_model(model, dataset["train_input"], dataset["train_label"])
test_accuracy = validate_kan_model(model, dataset["test_input"], dataset["test_label"])

print(f"Train Accuracy: {train_accuracy}")
print(f"Test Accuracy: {test_accuracy}")
# Out:
# Train Accuracy: 0.8715083599090576
# Test Accuracy: 0.9285714626312256
# Wall time: 2.46 s

# %% [markdown]
# ## 1.2.2 OpenAI CLIP | Smoking Dataset

# %%
import numpy as np
import torch
import os

import clip
from PIL import Image

# %%
device = "cuda:0" if torch.cuda.is_available() else "cpu"
clip_model, preprocess = clip.load("ViT-B/32", device=device)

image = preprocess(Image.open("./images/smoking_0125.jpg").convert("RGB")).unsqueeze(0).to(device)
image
# Out:
# tensor([[[[ 1.9157,  1.9157,  1.9303,  ...,  1.9303,  1.9303,  1.9303],
#           [ 1.9303,  1.9303,  1.9157,  ...,  1.9303,  1.9303,  1.9303],
#           [ 1.8865,  1.8281,  1.8573,  ...,  1.9303,  1.9303,  1.9303],
#           ...,
#           [-1.1353, -1.1499, -0.5806,  ...,  0.6311,  0.1931, -0.0259],
#           [-1.3981, -0.8434,  0.4851,  ...,  0.5581,  0.0617, -0.0113],
#           [-1.5149, -0.8726,  0.5435,  ...,  0.4851, -0.0405,  0.0179]],
#
#          [[ 2.0749,  2.0599,  2.0599,  ...,  2.0749,  2.0749,  2.0749],
#           [ 2.0599,  2.0749,  2.0749,  ...,  2.0749,  2.0749,  2.0749],
#           [ 2.0599,  2.0149,  2.0449,  ...,  2.0749,  2.0749,  2.0749],
#           ...,
#           [ 0.6041,  0.3340, -0.2363,  ...,  0.9343,  0.7542,  0.7392],
#           [-0.3264, -0.1913,  0.4691,  ...,  0.8442,  0.6191,  0.6792],
#           [-1.2418, -0.7766,  0.4090,  ...,  0.8292,  0.5891,  0.7092]],
#
#          [[ 2.0321,  2.0037,  2.0606,  ...,  2.0321,  2.0321,  2.0321],
#           [ 2.0606,  2.0037,  2.0179,  ...,  2.0321,  2.0321,  2.0321],
#           [ 2.0037,  1.9184,  1.9468,  ...,  2.0321,  2.0321,  2.0321],
#           ...,
#           [ 1.3069,  1.1505,  0.7950,  ...,  0.8092,  0.7523,  0.6101],
#           [ 1.1789,  1.1078,  0.7381,  ...,  0.7239,  0.6955,  0.5532],
#           [ 0.3115,  0.4253,  0.4537,  ...,  0.6812,  0.6812,  0.5532]]]],
#        device='cuda:0')

# %%
embed = clip_model.encode_image(image)
embed.shape
# Out:
# torch.Size([1, 512])

# %%
device = "cuda:0" if torch.cuda.is_available() else "cpu"
train_path = './smokers_dataset/Training'
test_path = './smokers_dataset/Testing'
dtype = torch.get_default_dtype()

# %%
def process_images(image_dir:str, clip_model, preprocess, device):
    """
    Process smoking dataset from directory using transforms
    
    Args:
        image_dir (str): Путь к директории с исходными изображениями.

    Returns:
        - Список обработанных тензоров изображений.
        - Список меток для изображений.
        - Список с именами файлов
    """
    
    processed_images = []
    labels = []
    filenames = []
    
    for filename in os.listdir(image_dir):
        if filename.lower().endswith(".jpg"):
            image_path = os.path.join(image_dir, filename)
            
            image = Image.open(image_path).convert("RGB")
            image = preprocess(image).unsqueeze(0).to(device)
            
            label = 0 if "notsmoking" in filename else 1 if "smoking" in filename else None
            if label is not None:
                labels.append(label)
                filenames.append(filename)
            else:
                print(f"Не удалось определить метку для файла: {filename}")
            
            with torch.no_grad():
                embedding = clip_model.encode_image(image).float().view(-1)
                processed_images.append(embedding)
            
#             print(f"processed: {filename}, value {processed_image}")
    
    return torch.stack(processed_images), np.array(labels), np.array(filenames)

# %%
train_images, train_labels, train_filenames = process_images(train_path, 
                                                             clip_model, 
                                                             preprocess, 
                                                             device)

test_images, test_labels, test_filenames = process_images(test_path, 
                                                          clip_model, 
                                                          preprocess, 
                                                          device)

# %%
print(f"Train Images Size: {train_images.shape}")
print(f"Test Images Size: {test_images.shape}")
# Out:
# Train Images Size: torch.Size([716, 512])
# Test Images Size: torch.Size([224, 512])

# %%
train_images, train_labels, train_filenames = shuffle_images(train_images, train_labels, train_filenames)
test_images, test_labels, test_filenames = shuffle_images(test_images, test_labels, test_filenames)

dataset = make_dataset_for_kan(train_images, train_labels, test_images, test_labels)

# %%
# %%time
model = KAN(width=[train_images.shape[1], 2], 
            grid=5, 
            k=3, 
            seed=42, 
            device=device, 
            auto_save=True, 
            ckpt_path='./KAN_model')

results = model.fit(dataset, 
                    opt="LBFGS", 
                    steps=50,  
                    loss_fn=torch.nn.CrossEntropyLoss(), 
                    lamb=0.02, batch=64, lr=1e-4)
# Out:
# checkpoint directory created: ./KAN_model
# saving model version 0.0
# | train_loss: 5.08e-01 | test_loss: 5.28e-01 | reg: 1.54e+01 | : 100%|█| 50/50 [00:09<00:00,  5.37it
# saving model version 0.1
# Wall time: 9.38 s

# %%
plot_kan_results(results)

# %%
# %%time

train_accuracy = validate_kan_model(model, dataset["train_input"], dataset["train_label"])
test_accuracy = validate_kan_model(model, dataset["test_input"], dataset["test_label"])

print(f"Train Accuracy: {train_accuracy}")
print(f"Test Accuracy: {test_accuracy}")
# Out:
# Train Accuracy: 0.9189943671226501
# Test Accuracy: 0.9241071939468384
# Wall time: 980 ms

# %% [markdown]
# ## 1.2.3 OpenAI CLIP | Satelite Dataset

# %%
import os
import torch
from torchvision import transforms
from PIL import Image
import numpy as np
import clip

# %%
data_path = './satellite_dataset/data'
classes = ['cloudy', 'desert', 'green_area', 'water']

# %%
device = "cuda:0" if torch.cuda.is_available() else "cpu"
clip_model, preprocess = clip.load("ViT-B/32", device=device)

# %%
def load_images(data_path, classes, clip_model, preprocess, device):
    processed_images = []
    labels = []
    filenames = []
    
    for label, class_name in enumerate(classes):
        class_dir = os.path.join(data_path, class_name)
        
        if not os.path.exists(class_dir):
            print(f"Directory '{class_name}' not found.")
            continue
        
        for file_name in os.listdir(class_dir):
            file_path = os.path.join(class_dir, file_name)
            
            try: 
                image = Image.open(file_path).convert("RGB")
                image = preprocess(image).unsqueeze(0).to(device)
                
                labels.append(label)
                filenames.append(file_name)
                
                with torch.no_grad():
                    embedding = clip_model.encode_image(image).float().view(-1)
                    processed_images.append(embedding)
                    
            except:
                print(f"Error processing file {file_name}: {e}")
                
    return torch.stack(processed_images), np.array(labels), np.array(filenames)

# %%
satelite_images, satelite_labels, satelite_filenames = load_images(data_path, 
                                                                   classes,
                                                                   clip_model, 
                                                                   preprocess, 
                                                                   device)

# %%
print(f"Satelite Images size: {satelite_images.shape}")
# Out:
# Satelite Images size: torch.Size([5631, 512])

# %%
def split_data(images_tensor, labels_tensor, file_names, test_size=0.2, random_state=42):
    """
    Разделение данных на train и test с сохранением баланса классов.
    """
    class_indices = {}
    for idx, label in enumerate(labels_tensor):
        label = label.item()
        if label not in class_indices:
            class_indices[label] = []
        class_indices[label].append(idx)
    
    train_indices = []
    test_indices = []
    for label, indices in class_indices.items():
        torch.manual_seed(random_state)
        indices = torch.tensor(indices)
        num_test = int(len(indices) * test_size)
        shuffled_indices = indices[torch.randperm(len(indices))]
        test_indices.extend(shuffled_indices[:num_test].tolist())
        train_indices.extend(shuffled_indices[num_test:].tolist())
    
    train_images_tensor = images_tensor[train_indices]
    test_images_tensor = images_tensor[test_indices]
    train_labels_tensor = labels_tensor[train_indices]
    test_labels_tensor = labels_tensor[test_indices]
    train_files = [file_names[i] for i in train_indices]
    test_files = [file_names[i] for i in test_indices]
    
    return (train_images_tensor, train_labels_tensor, train_files), (test_images_tensor, test_labels_tensor, test_files)

# %%
train_data, test_data = split_data(satelite_images, 
                                   satelite_labels,
                                   satelite_filenames)

# %%
train_labels = train_data[1]

unique_values, counts = np.unique(train_labels, return_counts=True)

for value, count in zip(unique_values, counts):
    print(f"Value {value} occurs {count} times.")
# Out:
# Value 0 occurs 1200 times.
# Value 1 occurs 905 times.
# Value 2 occurs 1200 times.
# Value 3 occurs 1200 times.

# %%
test_labels = test_data[1]

unique_values, counts = np.unique(test_labels, return_counts=True)

for value, count in zip(unique_values, counts):
    print(f"Value {value} occurs {count} times.")
# Out:
# Value 0 occurs 300 times.
# Value 1 occurs 226 times.
# Value 2 occurs 300 times.
# Value 3 occurs 300 times.

# %%
train_data[2]
# Out:
# ['train_21657.jpg',
#  'train_3036.jpg',
#  'train_4603.jpg',
#  'train_5180.jpg',
#  'train_11486.jpg',
#  'train_6987.jpg',
#  'train_39385.jpg',
#  'train_20675.jpg',
#  'train_39500.jpg',
#  'train_11150.jpg',
#  'train_437.jpg',
#  'train_11301.jpg',
#  'train_12713.jpg',
#  'train_3585.jpg',
#  'train_5680.jpg',
#  'train_23076.jpg',
#  'train_36004.jpg',
#  'train_21884.jpg',
#  'train_16989.jpg',
#  'train_18134.jpg',
#  'train_18281.jpg',
#  'train_29412.jpg',
#  'train_8064.jpg',
#  'train_4205.jpg',
#  'train_30155.jpg',
#  'train_31251.jpg',
#  'train_36687.jpg',
#  'train_36137.jpg',
#  'train_21872.jpg',
#  'train_20821.jpg',
#  'train_20008.jpg',
#  'train_2058.jpg',
#  'train_476.jpg',
#  'train_6573.jpg',
#  'train_7820.jpg',
#  'train_2396.jpg',
#  'train_12353.jpg',
#  'train_21098.jpg',
#  'train_4116.jpg',
#  'train_15974.jpg',
#  'train_27302.jpg',
#  'train_5220.jpg',
#  'train_30056.jpg',
#  'train_38446.jpg',
#  'train_9108.jpg',
#  'train_34079.jpg',
#  'train_8809.jpg',
#  'train_33597.jpg',
#  'train_31530.jpg',
#  'train_37495.jpg',
#  'train_38610.jpg',
#  'train_24472.jpg',
#  'train_22314.jpg',
#  'train_27397.jpg',
#  'train_601.jpg',
#  'train_9499.jpg',
#  'train_39520.jpg',
#  'train_5541.jpg',
#  'train_11937.jpg',
#  'train_36582.jpg',
#  'train_10269.jpg',
#  'train_4133.jpg',
#  'train_32993.jpg',
#  'train_17200.jpg',
#  'train_20554.jpg',
#  'train_6041.jpg',
#  'train_21555.jpg',
#  'train_7537.jpg',
#  'train_4843.jpg',
#  'train_14320.jpg',
#  'train_2699.jpg',
#  'train_30623.jpg',
#  'train_13130.jpg',
#  'train_36520.jpg',
#  'train_39288.jpg',
#  'train_17622.jpg',
#  'train_168.jpg',
#  'train_36862.jpg',
#  'train_18551.jpg',
#  'train_7063.jpg',
#  'train_39289.jpg',
#  'train_11979.jpg',
#  'train_984.jpg',
#  'train_29653.jpg',
#  'train_22646.jpg',
#  'train_11663.jpg',
#  'train_12536.jpg',
#  'train_16927.jpg',
#  'train_20472.jpg',
#  'train_4438.jpg',
#  'train_31954.jpg',
#  'train_19500.jpg',
#  'train_34770.jpg',
#  'train_5216.jpg',
#  'train_36545.jpg',
#  'train_32846.jpg',
#  'train_30762.jpg',
#  'train_33880.jpg',
#  'train_12365.jpg',
#  'train_8765.jpg',
#  'train_36363.jpg',
#  'train_37623.jpg',
#  'train_23478.jpg',
#  'train_20077.jpg',
#  'train_17769.jpg',
#  'train_34841.jpg',
#  'train_38735.jpg',
#  'train_7361.jpg',
#  'train_29171.jpg',
#  'train_38947.jpg',
#  'train_30902.jpg',
#  'train_34481.jpg',
#  'train_1968.jpg',
#  'train_29424.jpg',
#  'train_19911.jpg',
#  'train_36381.jpg',
#  'train_3951.jpg',
#  'train_28284.jpg',
#  'train_6438.jpg',
#  'train_23634.jpg',
#  'train_28537.jpg',
#  'train_19347.jpg',
#  'train_3657.jpg',
#  'train_23826.jpg',
#  'train_9950.jpg',
#  'train_24350.jpg',
#  'train_34728.jpg',
#  'train_10667.jpg',
#  'train_343.jpg',
#  'train_3327.jpg',
#  'train_1876.jpg',
#  'train_19442.jpg',
#  'train_32278.jpg',
#  'train_29014.jpg',
#  'train_23953.jpg',
#  'train_30946.jpg',
#  'train_28743.jpg',
#  'train_19513.jpg',
#  'train_16083.jpg',
#  'train_10661.jpg',
#  'train_38420.jpg',
#  'train_3613.jpg',
#  'train_32330.jpg',
#  'train_21867.jpg',
#  'train_28991.jpg',
#  'train_2337.jpg',
#  'train_14394.jpg',
#  'train_17584.jpg',
#  'train_18658.jpg',
#  'train_32961.jpg',
#  'train_24640.jpg',
#  'train_29917.jpg',
#  'train_37896.jpg',
#  'train_3278.jpg',
#  'train_34125.jpg',
#  'train_26916.jpg',
#  'train_758.jpg',
#  'train_21706.jpg',
#  'train_32613.jpg',
#  'train_25176.jpg',
#  'train_17131.jpg',
#  'train_9021.jpg',
#  'train_13300.jpg',
#  'train_39821.jpg',
#  'train_12502.jpg',
#  'train_22860.jpg',
#  'train_11706.jpg',
#  'train_28684.jpg',
#  'train_27810.jpg',
#  'train_8239.jpg',
#  'train_12611.jpg',
#  'train_9783.jpg',
#  'train_29162.jpg',
#  'train_25953.jpg',
#  'train_39035.jpg',
#  'train_14060.jpg',
#  'train_20690.jpg',
#  'train_26673.jpg',
#  'train_39690.jpg',
#  'train_22582.jpg',
#  'train_22590.jpg',
#  'train_5981.jpg',
#  'train_29842.jpg',
#  'train_40320.jpg',
#  'train_11312.jpg',
#  'train_30696.jpg',
#  'train_15911.jpg',
#  'train_15868.jpg',
#  'train_31387.jpg',
#  'train_4026.jpg',
#  'train_37555.jpg',
#  'train_17107.jpg',
#  'train_29808.jpg',
#  'train_12928.jpg',
#  'train_7597.jpg',
#  'train_16947.jpg',
#  'train_29080.jpg',
#  'train_14240.jpg',
#  'train_16890.jpg',
#  'train_30949.jpg',
#  'train_19085.jpg',
#  'train_9752.jpg',
#  'train_4013.jpg',
#  'train_7801.jpg',
#  'train_28686.jpg',
#  'train_23979.jpg',
#  'train_9258.jpg',
#  'train_6630.jpg',
#  'train_33425.jpg',
#  'train_5985.jpg',
#  'train_25827.jpg',
#  'train_29956.jpg',
#  'train_25815.jpg',
#  'train_11981.jpg',
#  'train_3078.jpg',
#  'train_24891.jpg',
#  'train_20522.jpg',
#  'train_28432.jpg',
#  'train_16188.jpg',
#  'train_179.jpg',
#  'train_4592.jpg',
#  'train_2655.jpg',
#  'train_4292.jpg',
#  'train_20320.jpg',
#  'train_15993.jpg',
#  'train_8608.jpg',
#  'train_3165.jpg',
#  'train_19785.jpg',
#  'train_16787.jpg',
#  'train_6681.jpg',
#  'train_27660.jpg',
#  'train_1450.jpg',
#  'train_15677.jpg',
#  'train_5780.jpg',
#  'train_38957.jpg',
#  'train_7365.jpg',
#  'train_35844.jpg',
#  'train_4873.jpg',
#  'train_12525.jpg',
#  'train_16997.jpg',
#  'train_1698.jpg',
#  'train_13647.jpg',
#  'train_12343.jpg',
#  'train_39256.jpg',
#  'train_8101.jpg',
#  'train_8287.jpg',
#  'train_40008.jpg',
#  'train_34681.jpg',
#  'train_3684.jpg',
#  'train_26416.jpg',
#  'train_28974.jpg',
#  'train_2965.jpg',
#  'train_26226.jpg',
#  'train_14.jpg',
#  'train_14659.jpg',
#  'train_11820.jpg',
#  'train_20601.jpg',
#  'train_9300.jpg',
#  'train_38329.jpg',
#  'train_38757.jpg',
#  'train_20371.jpg',
#  'train_12191.jpg',
#  'train_19642.jpg',
#  'train_26443.jpg',
#  'train_23566.jpg',
#  'train_37305.jpg',
#  'train_10389.jpg',
#  'train_14024.jpg',
#  'train_22967.jpg',
#  'train_30746.jpg',
#  'train_27223.jpg',
#  'train_34789.jpg',
#  'train_36802.jpg',
#  'train_29245.jpg',
#  'train_20957.jpg',
#  'train_30882.jpg',
#  'train_1916.jpg',
#  'train_18102.jpg',
#  'train_13497.jpg',
#  'train_20054.jpg',
#  'train_38833.jpg',
#  'train_31713.jpg',
#  'train_15751.jpg',
#  'train_11512.jpg',
#  'train_29292.jpg',
#  'train_12.jpg',
#  'train_11904.jpg',
#  'train_3136.jpg',
#  'train_23254.jpg',
#  'train_9761.jpg',
#  'train_36994.jpg',
#  'train_33341.jpg',
#  'train_33299.jpg',
#  'train_19502.jpg',
#  'train_18572.jpg',
#  'train_38032.jpg',
#  'train_28680.jpg',
#  'train_18150.jpg',
#  'train_20826.jpg',
#  'train_1486.jpg',
#  'train_13442.jpg',
#  'train_34303.jpg',
#  'train_10816.jpg',
#  'train_39946.jpg',
#  'train_27399.jpg',
#  'train_1722.jpg',
#  'train_38606.jpg',
#  'train_26564.jpg',
#  'train_19027.jpg',
#  'train_38541.jpg',
#  'train_17222.jpg',
#  'train_4626.jpg',
#  'train_20609.jpg',
#  'train_4587.jpg',
#  'train_35367.jpg',
#  'train_35508.jpg',
#  'train_24490.jpg',
#  'train_6891.jpg',
#  'train_38153.jpg',
#  'train_1836.jpg',
#  'train_35153.jpg',
#  'train_14210.jpg',
#  'train_9587.jpg',
#  'train_14975.jpg',
#  'train_8519.jpg',
#  'train_20523.jpg',
#  'train_8627.jpg',
#  'train_2664.jpg',
#  'train_20352.jpg',
#  'train_19863.jpg',
#  'train_34216.jpg',
#  'train_25595.jpg',
#  'train_16195.jpg',
#  'train_8773.jpg',
#  'train_29002.jpg',
#  'train_35846.jpg',
#  'train_1256.jpg',
#  'train_7708.jpg',
#  'train_32698.jpg',
#  'train_4007.jpg',
#  'train_1663.jpg',
#  'train_22041.jpg',
#  'train_14592.jpg',
#  'train_5675.jpg',
#  'train_35205.jpg',
#  'train_36382.jpg',
#  'train_18887.jpg',
#  'train_33296.jpg',
#  'train_17722.jpg',
#  'train_17086.jpg',
#  'train_14787.jpg',
#  'train_34585.jpg',
#  'train_10263.jpg',
#  'train_15393.jpg',
#  'train_790.jpg',
#  'train_14238.jpg',
#  'train_10485.jpg',
#  'train_24094.jpg',
#  'train_5391.jpg',
#  'train_5368.jpg',
#  'train_118.jpg',
#  'train_14591.jpg',
#  'train_6339.jpg',
#  'train_10908.jpg',
#  'train_7172.jpg',
#  'train_32309.jpg',
#  'train_38657.jpg',
#  'train_27556.jpg',
#  'train_5025.jpg',
#  'train_11132.jpg',
#  'train_20756.jpg',
#  'train_3922.jpg',
#  'train_16199.jpg',
#  'train_18073.jpg',
#  'train_22193.jpg',
#  'train_25557.jpg',
#  'train_16628.jpg',
#  'train_2431.jpg',
#  'train_36559.jpg',
#  'train_1360.jpg',
#  'train_18661.jpg',
#  'train_17406.jpg',
#  'train_14654.jpg',
#  'train_20608.jpg',
#  'train_1140.jpg',
#  'train_7192.jpg',
#  'train_9006.jpg',
#  'train_20655.jpg',
#  'train_34355.jpg',
#  'train_6105.jpg',
#  'train_15590.jpg',
#  'train_1092.jpg',
#  'train_31197.jpg',
#  'train_35811.jpg',
#  'train_34208.jpg',
#  'train_29680.jpg',
#  'train_31184.jpg',
#  'train_38925.jpg',
#  'train_2267.jpg',
#  'train_17505.jpg',
#  'train_30001.jpg',
#  'train_20496.jpg',
#  'train_29861.jpg',
#  'train_24917.jpg',
#  'train_25399.jpg',
#  'train_16865.jpg',
#  'train_4038.jpg',
#  'train_17182.jpg',
#  'train_9132.jpg',
#  'train_30686.jpg',
#  'train_9422.jpg',
#  'train_3297.jpg',
#  'train_9713.jpg',
#  'train_14942.jpg',
#  'train_25843.jpg',
#  'train_17897.jpg',
#  'train_3512.jpg',
#  'train_22972.jpg',
#  'train_16693.jpg',
#  'train_18475.jpg',
#  'train_38089.jpg',
#  'train_23608.jpg',
#  'train_5235.jpg',
#  'train_17269.jpg',
#  'train_10021.jpg',
#  'train_9844.jpg',
#  'train_24299.jpg',
#  'train_14509.jpg',
#  'train_453.jpg',
#  'train_21871.jpg',
#  'train_9943.jpg',
#  'train_26512.jpg',
#  'train_30244.jpg',
#  'train_26882.jpg',
#  'train_13282.jpg',
#  'train_11326.jpg',
#  'train_27945.jpg',
#  'train_40255.jpg',
#  'train_14090.jpg',
#  'train_16766.jpg',
#  'train_18768.jpg',
#  'train_8836.jpg',
#  'train_30437.jpg',
#  'train_17901.jpg',
#  'train_7387.jpg',
#  'train_7759.jpg',
#  'train_21750.jpg',
#  'train_20179.jpg',
#  'train_32431.jpg',
#  'train_3176.jpg',
#  'train_30274.jpg',
#  'train_6274.jpg',
#  'train_27254.jpg',
#  'train_13292.jpg',
#  'train_13560.jpg',
#  'train_20250.jpg',
#  'train_29201.jpg',
#  'train_10547.jpg',
#  'train_3609.jpg',
#  'train_15408.jpg',
#  'train_10609.jpg',
#  'train_1598.jpg',
#  'train_10225.jpg',
#  'train_4641.jpg',
#  'train_15364.jpg',
#  'train_6802.jpg',
#  'train_24936.jpg',
#  'train_6520.jpg',
#  'train_35753.jpg',
#  'train_18084.jpg',
#  'train_15171.jpg',
#  'train_10096.jpg',
#  'train_7096.jpg',
#  'train_6279.jpg',
#  'train_3542.jpg',
#  'train_23490.jpg',
#  'train_14978.jpg',
#  'train_38405.jpg',
#  'train_14932.jpg',
#  'train_8588.jpg',
#  'train_27379.jpg',
#  'train_15137.jpg',
#  'train_36600.jpg',
#  'train_8478.jpg',
#  'train_8961.jpg',
#  'train_39222.jpg',
#  'train_17301.jpg',
#  'train_33560.jpg',
#  'train_16892.jpg',
#  'train_14991.jpg',
#  'train_36964.jpg',
#  'train_2236.jpg',
#  'train_7859.jpg',
#  'train_3592.jpg',
#  'train_28923.jpg',
#  'train_7675.jpg',
#  'train_11740.jpg',
#  'train_11317.jpg',
#  'train_19756.jpg',
#  'train_3932.jpg',
#  'train_20483.jpg',
#  'train_12975.jpg',
#  'train_20247.jpg',
#  'train_19363.jpg',
#  'train_18942.jpg',
#  'train_3395.jpg',
#  'train_39830.jpg',
#  'train_15562.jpg',
#  'train_19392.jpg',
#  'train_7743.jpg',
#  'train_10293.jpg',
#  'train_32375.jpg',
#  'train_37683.jpg',
#  'train_24013.jpg',
#  'train_23664.jpg',
#  'train_35179.jpg',
#  'train_31365.jpg',
#  'train_4303.jpg',
#  'train_19813.jpg',
#  'train_29550.jpg',
#  'train_108.jpg',
#  'train_10856.jpg',
#  'train_17033.jpg',
#  'train_38400.jpg',
#  'train_21385.jpg',
#  'train_28555.jpg',
#  'train_1756.jpg',
#  'train_26411.jpg',
#  'train_29733.jpg',
#  'train_2636.jpg',
#  'train_17702.jpg',
#  'train_28454.jpg',
#  'train_10563.jpg',
#  'train_37465.jpg',
#  'train_5670.jpg',
#  'train_10538.jpg',
#  'train_17552.jpg',
#  'train_24945.jpg',
#  'train_10889.jpg',
#  'train_38166.jpg',
#  'train_11325.jpg',
#  'train_20612.jpg',
#  'train_16031.jpg',
#  'train_16659.jpg',
#  'train_10081.jpg',
#  'train_24139.jpg',
#  'train_12112.jpg',
#  'train_21972.jpg',
#  'train_9843.jpg',
#  'train_16486.jpg',
#  'train_31588.jpg',
#  'train_36754.jpg',
#  'train_1479.jpg',
#  'train_38263.jpg',
#  'train_31358.jpg',
#  'train_28329.jpg',
#  'train_5803.jpg',
#  'train_9346.jpg',
#  'train_29355.jpg',
#  'train_9229.jpg',
#  'train_13370.jpg',
#  'train_28762.jpg',
#  'train_17504.jpg',
#  'train_30828.jpg',
#  'train_19069.jpg',
#  'train_32139.jpg',
#  'train_30862.jpg',
#  'train_1580.jpg',
#  'train_8481.jpg',
#  'train_2021.jpg',
#  'train_14977.jpg',
#  'train_5925.jpg',
#  'train_20703.jpg',
#  'train_36096.jpg',
#  'train_34498.jpg',
#  'train_21335.jpg',
#  'train_35105.jpg',
#  'train_8220.jpg',
#  'train_24396.jpg',
#  'train_27120.jpg',
#  'train_8872.jpg',
#  'train_36945.jpg',
#  'train_19694.jpg',
#  'train_39054.jpg',
#  'train_16844.jpg',
#  'train_10581.jpg',
#  'train_34671.jpg',
#  'train_10566.jpg',
#  'train_16112.jpg',
#  'train_16604.jpg',
#  'train_8658.jpg',
#  'train_3099.jpg',
#  'train_33260.jpg',
#  'train_31368.jpg',
#  'train_29523.jpg',
#  'train_18626.jpg',
#  'train_28318.jpg',
#  'train_24693.jpg',
#  'train_4448.jpg',
#  'train_12097.jpg',
#  'train_12016.jpg',
#  'train_1776.jpg',
#  'train_8731.jpg',
#  'train_34058.jpg',
#  'train_2911.jpg',
#  'train_18258.jpg',
#  'train_28463.jpg',
#  'train_16735.jpg',
#  'train_13613.jpg',
#  'train_6506.jpg',
#  'train_38073.jpg',
#  'train_20895.jpg',
#  'train_22455.jpg',
#  'train_24649.jpg',
#  'train_18939.jpg',
#  'train_20841.jpg',
#  'train_40236.jpg',
#  'train_14895.jpg',
#  'train_14862.jpg',
#  'train_1921.jpg',
#  'train_38823.jpg',
#  'train_18913.jpg',
#  'train_17237.jpg',
#  'train_19504.jpg',
#  'train_6888.jpg',
#  'train_10128.jpg',
#  'train_35499.jpg',
#  'train_10493.jpg',
#  'train_6073.jpg',
#  'train_1777.jpg',
#  'train_11352.jpg',
#  'train_12009.jpg',
#  'train_28182.jpg',
#  'train_28072.jpg',
#  'train_4834.jpg',
#  'train_15770.jpg',
#  'train_77.jpg',
#  'train_10043.jpg',
#  'train_38893.jpg',
#  'train_1336.jpg',
#  'train_26814.jpg',
#  'train_17083.jpg',
#  'train_23310.jpg',
#  'train_17324.jpg',
#  'train_17762.jpg',
#  'train_28511.jpg',
#  'train_37888.jpg',
#  'train_25041.jpg',
#  'train_25109.jpg',
#  'train_1339.jpg',
#  'train_13475.jpg',
#  'train_3406.jpg',
#  'train_23418.jpg',
#  'train_29732.jpg',
#  'train_1520.jpg',
#  'train_22809.jpg',
#  'train_1704.jpg',
#  'train_13792.jpg',
#  'train_32819.jpg',
#  'train_26.jpg',
#  'train_34205.jpg',
#  'train_20310.jpg',
#  'train_36537.jpg',
#  'train_35426.jpg',
#  'train_16964.jpg',
#  'train_22263.jpg',
#  'train_15747.jpg',
#  'train_7303.jpg',
#  'train_534.jpg',
#  'train_18329.jpg',
#  'train_8158.jpg',
#  'train_37900.jpg',
#  'train_37942.jpg',
#  'train_31369.jpg',
#  'train_3366.jpg',
#  'train_22386.jpg',
#  'train_34176.jpg',
#  'train_11844.jpg',
#  'train_37445.jpg',
#  'train_32617.jpg',
#  'train_23147.jpg',
#  'train_1717.jpg',
#  'train_12500.jpg',
#  'train_38217.jpg',
#  'train_39361.jpg',
#  'train_26562.jpg',
#  'train_18386.jpg',
#  'train_32670.jpg',
#  'train_11240.jpg',
#  'train_13248.jpg',
#  'train_24249.jpg',
#  'train_36603.jpg',
#  'train_20748.jpg',
#  'train_19906.jpg',
#  'train_15201.jpg',
#  'train_20177.jpg',
#  'train_18183.jpg',
#  'train_25106.jpg',
#  'train_15247.jpg',
#  'train_16901.jpg',
#  'train_39920.jpg',
#  'train_11549.jpg',
#  'train_8013.jpg',
#  'train_14667.jpg',
#  'train_33933.jpg',
#  'train_21806.jpg',
#  'train_28936.jpg',
#  'train_29850.jpg',
#  'train_11569.jpg',
#  'train_40475.jpg',
#  'train_39334.jpg',
#  'train_10421.jpg',
#  'train_16387.jpg',
#  'train_25389.jpg',
#  'train_16575.jpg',
#  'train_34772.jpg',
#  'train_18223.jpg',
#  'train_27355.jpg',
#  'train_7090.jpg',
#  'train_13785.jpg',
#  'train_26216.jpg',
#  'train_22118.jpg',
#  'train_2234.jpg',
#  'train_32009.jpg',
#  'train_8755.jpg',
#  'train_17513.jpg',
#  'train_18954.jpg',
#  'train_38808.jpg',
#  'train_5294.jpg',
#  'train_22250.jpg',
#  'train_39781.jpg',
#  'train_37423.jpg',
#  'train_2550.jpg',
#  'train_39061.jpg',
#  'train_24001.jpg',
#  'train_827.jpg',
#  'train_1550.jpg',
#  'train_28488.jpg',
#  'train_13602.jpg',
#  'train_37879.jpg',
#  'train_17662.jpg',
#  'train_4051.jpg',
#  'train_18567.jpg',
#  'train_26108.jpg',
#  'train_234.jpg',
#  'train_24897.jpg',
#  'train_31129.jpg',
#  'train_23312.jpg',
#  'train_7419.jpg',
#  'train_28089.jpg',
#  'train_7367.jpg',
#  'train_19299.jpg',
#  'train_16418.jpg',
#  'train_32973.jpg',
#  'train_38467.jpg',
#  'train_28244.jpg',
#  'train_8930.jpg',
#  'train_35495.jpg',
#  'train_25029.jpg',
#  'train_16644.jpg',
#  'train_8937.jpg',
#  'train_13219.jpg',
#  'train_23978.jpg',
#  'train_2100.jpg',
#  'train_1670.jpg',
#  'train_26159.jpg',
#  'train_39153.jpg',
#  'train_2562.jpg',
#  'train_38650.jpg',
#  'train_3849.jpg',
#  'train_23805.jpg',
#  'train_22371.jpg',
#  'train_39028.jpg',
#  'train_18344.jpg',
#  'train_3473.jpg',
#  'train_3995.jpg',
#  'train_30724.jpg',
#  'train_17141.jpg',
#  'train_35457.jpg',
#  'train_36016.jpg',
#  'train_28832.jpg',
#  'train_14091.jpg',
#  'train_23646.jpg',
#  'train_29833.jpg',
#  'train_17009.jpg',
#  'train_29187.jpg',
#  'train_21812.jpg',
#  'train_31756.jpg',
#  'train_2424.jpg',
#  'train_15278.jpg',
#  'train_14634.jpg',
#  'train_24443.jpg',
#  'train_10231.jpg',
#  'train_26460.jpg',
#  'train_11305.jpg',
#  'train_34669.jpg',
#  'train_13628.jpg',
#  'train_15012.jpg',
#  'train_15999.jpg',
#  'train_36445.jpg',
#  'train_11307.jpg',
#  'train_31339.jpg',
#  'train_21888.jpg',
#  'train_17569.jpg',
#  'train_6829.jpg',
#  'train_31822.jpg',
#  'train_28534.jpg',
#  'train_27602.jpg',
#  'train_15742.jpg',
#  'train_31228.jpg',
#  'train_13464.jpg',
#  'train_8370.jpg',
#  'train_13124.jpg',
#  'train_21502.jpg',
#  'train_284.jpg',
#  'train_15077.jpg',
#  'train_3098.jpg',
#  'train_23981.jpg',
#  'train_21071.jpg',
#  'train_8544.jpg',
#  'train_16023.jpg',
#  'train_32385.jpg',
#  'train_21804.jpg',
#  'train_32011.jpg',
#  'train_23877.jpg',
#  'train_27202.jpg',
#  'train_18170.jpg',
#  'train_31030.jpg',
#  'train_5648.jpg',
#  'train_6306.jpg',
#  'train_37640.jpg',
#  'train_4534.jpg',
#  'train_26528.jpg',
#  'train_28518.jpg',
#  'train_1969.jpg',
#  'train_25602.jpg',
#  'train_2231.jpg',
#  'train_38890.jpg',
#  'train_10224.jpg',
#  'train_6954.jpg',
#  'train_23081.jpg',
#  'train_9852.jpg',
#  'train_6093.jpg',
#  'train_11260.jpg',
#  'train_25207.jpg',
#  'train_30730.jpg',
#  'train_13407.jpg',
#  'train_37190.jpg',
#  'train_37841.jpg',
#  'train_29061.jpg',
#  'train_36388.jpg',
#  'train_28215.jpg',
#  'train_34936.jpg',
#  'train_25626.jpg',
#  'train_7858.jpg',
#  'train_11686.jpg',
#  'train_22160.jpg',
#  'train_6068.jpg',
#  'train_23806.jpg',
#  'train_13502.jpg',
#  'train_19000.jpg',
#  'train_18175.jpg',
#  'train_10166.jpg',
#  'train_22773.jpg',
#  'train_16321.jpg',
#  'train_32704.jpg',
#  'train_40416.jpg',
#  'train_1378.jpg',
#  'train_13114.jpg',
#  'train_17016.jpg',
#  'train_8499.jpg',
#  'train_34754.jpg',
#  'train_7701.jpg',
#  'train_14542.jpg',
#  'train_34803.jpg',
#  'train_33463.jpg',
#  'train_10173.jpg',
#  'train_7284.jpg',
#  'train_12770.jpg',
#  'train_21591.jpg',
#  'train_1086.jpg',
#  'train_12924.jpg',
#  'train_26957.jpg',
#  'train_19693.jpg',
#  'train_15994.jpg',
#  'train_10621.jpg',
#  'train_15165.jpg',
#  'train_22728.jpg',
#  'train_26572.jpg',
#  'train_29881.jpg',
#  'train_11218.jpg',
#  'train_8972.jpg',
#  'train_22486.jpg',
#  'train_10406.jpg',
#  'train_24390.jpg',
#  'train_38788.jpg',
#  'train_13167.jpg',
#  'train_16251.jpg',
#  'train_23417.jpg',
#  'train_26436.jpg',
#  'train_20397.jpg',
#  'train_13006.jpg',
#  'train_3128.jpg',
#  'train_4809.jpg',
#  'train_11161.jpg',
#  'train_28292.jpg',
#  'train_26084.jpg',
#  'train_11492.jpg',
#  'train_23980.jpg',
#  'train_28851.jpg',
#  'train_18672.jpg',
#  'train_29368.jpg',
#  'train_20216.jpg',
#  'train_13047.jpg',
#  'train_7258.jpg',
#  'train_32257.jpg',
#  'train_12119.jpg',
#  'train_29242.jpg',
#  'train_15885.jpg',
#  'train_16935.jpg',
#  'train_27239.jpg',
#  'train_20581.jpg',
#  'train_39892.jpg',
#  'train_34391.jpg',
#  'train_26892.jpg',
#  'train_35551.jpg',
#  'train_30534.jpg',
#  'train_22405.jpg',
#  'train_17067.jpg',
#  'train_30083.jpg',
#  'train_19621.jpg',
#  'train_11644.jpg',
#  'train_10070.jpg',
#  'train_21908.jpg',
#  'train_413.jpg',
#  'train_25327.jpg',
#  'train_30809.jpg',
#  'train_2366.jpg',
#  'train_8546.jpg',
#  'train_38108.jpg',
#  'train_40203.jpg',
#  'train_32828.jpg',
#  'train_7959.jpg',
#  'train_21922.jpg',
#  'train_6850.jpg',
#  'train_13011.jpg',
#  'train_23434.jpg',
#  'train_29353.jpg',
#  'train_29109.jpg',
#  'train_10555.jpg',
#  'train_12239.jpg',
#  'train_40436.jpg',
#  'train_21151.jpg',
#  'train_30798.jpg',
#  'train_2900.jpg',
#  'train_28765.jpg',
#  'train_10710.jpg',
#  'train_28485.jpg',
#  'train_37903.jpg',
#  'train_13312.jpg',
#  'train_40327.jpg',
#  'train_15477.jpg',
#  'train_16059.jpg',
#  'train_23436.jpg',
#  'train_24270.jpg',
#  'train_34082.jpg',
#  'train_10891.jpg',
#  'train_18154.jpg',
#  'train_16872.jpg',
#  'train_3014.jpg',
#  'train_16253.jpg',
#  'train_1297.jpg',
#  'train_40025.jpg',
#  'train_7121.jpg',
#  'train_6736.jpg',
#  'train_35525.jpg',
#  'train_16397.jpg',
#  'train_20239.jpg',
#  'train_16043.jpg',
#  'train_16567.jpg',
#  'train_31887.jpg',
#  'train_40041.jpg',
#  'train_26540.jpg',
#  'train_28057.jpg',
#  'train_22123.jpg',
#  'train_22808.jpg',
#  'train_717.jpg',
#  'train_17794.jpg',
#  'train_7656.jpg',
#  'train_9179.jpg',
#  'train_30614.jpg',
#  'train_38804.jpg',
#  'train_12068.jpg',
#  'train_9868.jpg',
#  'train_21364.jpg',
#  'train_21868.jpg',
#  'train_14403.jpg',
#  'train_18402.jpg',
#  'train_1707.jpg',
#  'train_860.jpg',
#  ...]

# %%
train_images, train_labels, _ = shuffle_images(train_data[0], train_data[1])
test_images, test_labels, _ = shuffle_images(test_data[0], test_data[1])

dataset = make_dataset_for_kan(train_images, train_labels, test_images, test_labels)

# %%
# %%time
model = KAN(width=[train_images.shape[1], 4], 
            grid=5, 
            k=3, 
            seed=42, 
            device=device, 
            auto_save=True, 
            ckpt_path='./KAN_model')

results = model.fit(dataset, 
                    opt="LBFGS", 
                    steps=50,  
                    loss_fn=torch.nn.CrossEntropyLoss(), 
                    lamb=0.02, batch=64, lr=1e-4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <timed exec> in <module>
#
# NameError: name 'MultKAN' is not defined

# %% [markdown]
# ## Символьное представление, формулы для классов и график

# %% [markdown]
# Немного странно это работает, можно скипнуть

# %%
lib = ['x','x^2','x^3','x^4','exp','log','sqrt','tanh','sin','abs']
model.auto_symbolic(lib=lib)

# %%
model.plot()

# %%
X = dataset['train_input']
y = dataset['train_label']

# %%
dataset["train_label"][:10]

# %%
formula1, formula2 = model.symbolic_formula()[0]

# %%
for i in range(1):
    print(f"filename: {test_filenames[i]}")
    print(f"Input: {test_images[i]}")
    print(f"Answer: {test_labels[i]}")
    
    indices = []
    syms = []
    for sym in x_symbols:
        syms.append(sym)
        indices.append(int(str(sym).split('_')[1]))
        
    subs_dict = {sym: test_images[i, idx-1] for sym, idx in zip(syms, indices)}
    
    logit1 = np.array(formula1.subs(subs_dict), dtype=float)
    logit2 = np.array(formula2.subs(subs_dict), dtype=float)
    print(f"Predict: {logit1}, {logit2}")
    print(subs_dict)
    print()

# %%
# train_images.shape[1]
import sympy as sp

x_symbols = sorted(sp.symbols(f"x_1:{512+1}"), key=lambda sym: str(sym))

# %%
subs_dict = {x_symbols[i]: X[0, i] for i in range(len(x_symbols))}
subs_dict

# %%
# %%time
ans = np.array(formula1.subs(subs_dict), dtype=float)
ans

# %%
import sympy as sp

x_symbols = sp.symbols(f"x_1:{50+1}")

# how accurate is this formula?
def acc(formula1, formula2, X, y):
    batch = X.shape[0]
    correct = 0
    for i in range(batch):
        subs_dict = {x_symbols[j]: X[i, j] for j in range(len(x_symbols))}
        
        logit1 = np.array(formula1.subs(subs_dict), dtype=float)
        logit2 = np.array(formula2.subs(subs_dict), dtype=float)
        correct += (logit2 > logit1) == y[i]
    return correct/batch

print('train acc of the formula:', acc(formula1, formula2, dataset['train_input'], dataset['train_label']))
print('test acc of the formula:', acc(formula1, formula2, dataset['test_input'], dataset['test_label']))

# %% [markdown]
# # Сравнение с MLP

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset

# %%
class ClassificationLayer(nn.Module):
    def __init__(self, input_dim=512, num_classes=2):
        super(ClassificationLayer, self).__init__()
        self.fc = nn.Linear(input_dim, num_classes)

    def forward(self, x):
        return self.fc(x)

# %%
input_dim = 512
num_classes = 2
batch_size = 16
learning_rate = 1.0
epochs = 50

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

dataset_nn = TensorDataset(dataset["train_input"].to(device), torch.tensor(dataset["train_label"]).to(device, dtype=torch.long))
dataloader = DataLoader(dataset_nn, batch_size=batch_size, shuffle=True)
# Out:
# C:\Users\kvard\AppData\Local\Temp/ipykernel_4488/1747118571.py:3: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   dataset_nn = TensorDataset(dataset["train_input"].to(device), torch.tensor(dataset["train_label"]).to(device, dtype=torch.long))

# %%
# %%time
# Создаем модель и переносим на GPU
model = ClassificationLayer(input_dim=input_dim, num_classes=num_classes).to(device)


# Определяем функцию потерь и оптимизатор
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# Обучение модели
model.train()
for epoch in range(epochs):
    total_loss = 0.0
    for inputs, labels in dataloader:
        # Обнуляем градиенты
        optimizer.zero_grad()

        # Прямой проход
        outputs = model(inputs)

        # Вычисление функции потерь
        loss = criterion(outputs, labels)

        # Обратный проход и шаг оптимизации
        loss.backward()
        optimizer.step()

        total_loss += loss.item()

    print(f"Epoch {epoch + 1}/{epochs}, Loss: {total_loss / len(dataloader):.4f}")

    print("Training complete.")
# Out:
# Epoch 1/50, Loss: 6.3719
# Training complete.
# Epoch 2/50, Loss: 2.8395
# Training complete.
# Epoch 3/50, Loss: 2.5994
# Training complete.
# Epoch 4/50, Loss: 2.4542
# Training complete.
# Epoch 5/50, Loss: 1.9004
# Training complete.
# Epoch 6/50, Loss: 0.5524
# Training complete.
# Epoch 7/50, Loss: 0.6105
# Training complete.
# Epoch 8/50, Loss: 0.4237
# Training complete.
# Epoch 9/50, Loss: 0.2101
# Training complete.
# Epoch 10/50, Loss: 0.1644
# Training complete.
# Epoch 11/50, Loss: 0.6948
# Training complete.
# Epoch 12/50, Loss: 0.3748
# Training complete.
# Epoch 13/50, Loss: 1.0151
# Training complete.
# Epoch 14/50, Loss: 0.7819
# Training complete.
# Epoch 15/50, Loss: 0.8092
# Training complete.
# Epoch 16/50, Loss: 0.0099
# Training complete.
# Epoch 17/50, Loss: 0.0461
# Training complete.
# Epoch 18/50, Loss: 0.0818
# Training complete.
# Epoch 19/50, Loss: 0.0167
# Training complete.
# Epoch 20/50, Loss: 0.1372
# Training complete.
# Epoch 21/50, Loss: 0.2314
# Training complete.
# Epoch 22/50, Loss: 1.1780
# Training complete.
# Epoch 23/50, Loss: 2.0334
# Training complete.
# Epoch 24/50, Loss: 0.4501
# Training complete.
# Epoch 25/50, Loss: 0.1135
# Training complete.
# Epoch 26/50, Loss: 0.3695
# Training complete.
# Epoch 27/50, Loss: 0.5776
# Training complete.
# Epoch 28/50, Loss: 0.0512
# Training complete.
# Epoch 29/50, Loss: 0.3055
# Training complete.
# Epoch 30/50, Loss: 0.5068
# Training complete.
# Epoch 31/50, Loss: 0.6635
# Training complete.
# Epoch 32/50, Loss: 0.7643
# Training complete.
# Epoch 33/50, Loss: 0.1784
# Training complete.
# Epoch 34/50, Loss: 0.1727
# Training complete.
# Epoch 35/50, Loss: 0.4224
# Training complete.
# Epoch 36/50, Loss: 0.3825
# Training complete.
# Epoch 37/50, Loss: 0.0137
# Training complete.
# Epoch 38/50, Loss: 0.1628
# Training complete.
# Epoch 39/50, Loss: 0.2020
# Training complete.
# Epoch 40/50, Loss: 0.2843
# Training complete.
# Epoch 41/50, Loss: 0.4326
# Training complete.
# Epoch 42/50, Loss: 0.2174
# Training complete.
# Epoch 43/50, Loss: 0.1706
# Training complete.
# Epoch 44/50, Loss: 0.1860
# Training complete.
# Epoch 45/50, Loss: 0.6976
# Training complete.
# Epoch 46/50, Loss: 0.9506
# Training complete.
# Epoch 47/50, Loss: 0.5900
# Training complete.
# Epoch 48/50, Loss: 0.0000
# Training complete.
# Epoch 49/50, Loss: 0.0000
# Training complete.
# Epoch 50/50, Loss: 0.0000
# Training complete.
# Wall time: 2.96 s

# %%
def validate_model(model, dataloader, device):
    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for inputs, labels in dataloader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    accuracy = correct / total
    return accuracy

test_dataset = TensorDataset(dataset["test_input"].to(device), torch.tensor(dataset["test_label"]).to(device, dtype=torch.long))
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

train_accuracy = validate_model(model, dataloader, device)
test_accuracy = validate_model(model, test_dataloader, device)
print(f"Train Accuracy: {train_accuracy}")
print(f"Test Accuracy: {test_accuracy}")
# Out:
# Train Accuracy: 1.0
# Test Accuracy: 1.0
# C:\Users\kvard\AppData\Local\Temp/ipykernel_4488/209968391.py:15: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   test_dataset = TensorDataset(dataset["test_input"].to(device), torch.tensor(dataset["test_label"]).to(device, dtype=torch.long))

# %%
for inputs, labels in test_dataloader:
    inputs, labels = inputs.to(device), labels.to(device)
    outputs = model(inputs)
    _, predicted = torch.max(outputs, 1)
    
    print(outputs)
    print(predicted)
    print(labels)
    break

# %% [markdown]
# # Indoor Outdoor

# %%
import clip
from PIL import Image
import numpy as np
import os

device = "cuda:0" if torch.cuda.is_available() else "cpu"
indoor_data_path = 'C:/Users/kvard/VK Education Course/Neural Networks/indoor_outdoor_dataset/indoor'
out_data_path = 'C:/Users/kvard/VK Education Course/Neural Networks/indoor_outdoor_dataset/outdoor'
dtype = torch.get_default_dtype()

images_embedings_model, preprocess = clip.load("ViT-B/32", device=device)

def process_images(model, directory):
    
    images = []
    labels = []
    filenames = []
            
    for filename in os.listdir(directory):
        if filename.endswith(".jpg"):
            filepath = os.path.join(directory, filename)
            
            # Преобразование изображения
            image = Image.open(filepath).convert("RGB")
            images.append(preprocess(image))
                   
            # Присвоение метки
            if "indoor_outdoor_dataset/outdoor" in directory:
                label = 0
            
            else if "indoor_outdoor_dataset/indoor" in directory:
                label = 1
            
            if label is not None:
                labels.append(label)
                filenames.append(filename)
            else:
                print(f"Не удалось определить метку для файла: {filename}")
    
            if len(labels) == 2500:
                break
                
    image_input = torch.tensor(np.stack(images)).cuda()
    
    with torch.no_grad():
        embeddings = model.encode_image(image_input).float()
    
    return embeddings, np.array(labels), np.array(filenames)

# %%
indoor_images, indoor_labels, indoor_filenames = process_images(images_embedings_model, indoor_data_path)

# %%
indoor_images.shape
# Out:
# torch.Size([2500, 512])

# %%
np.unique(indoor_labels)
# Out:
# array([0])

# %%
outdoor_images, outdoor_labels, outdoor_filenames = process_images(images_embedings_model, out_data_path)

# %%
outdoor_images.shape
# Out:
# torch.Size([2500, 512])

# %%
np.unique(outdoor_labels)
# Out:
# array([1])

# %%
indoor_images.cpu().numpy()
# Out:
# array([[-0.2154541 , -0.2290039 ,  0.02531433, ...,  0.14746094,
#          0.09143066, -0.22045898],
#        [-0.22888184,  0.14257812,  0.16052246, ...,  0.4975586 ,
#          0.3942871 , -0.14123535],
#        [-0.63916016,  0.12878418,  0.26049805, ..., -0.31030273,
#          0.40405273, -0.14758301],
#        ...,
#        [-0.1352539 ,  0.2536621 , -0.04812622, ...,  0.2512207 ,
#         -0.10681152,  0.05599976],
#        [ 0.2088623 ,  0.4116211 ,  0.15661621, ...,  0.05236816,
#         -0.09814453,  0.04455566],
#        [ 0.53515625,  0.16320801,  0.2199707 , ...,  0.5722656 ,
#          0.07751465, -0.20629883]], dtype=float32)

# %%
images = np.stack((indoor_images.cpu().numpy(), outdoor_images.cpu().numpy()), axis=0).reshape(2 * len(outdoor_labels), 512)
labels = np.stack((indoor_labels, outdoor_labels), axis=0).flatten()

# %%
indices = np.arange(len(labels))
np.random.shuffle(indices)

images = images[indices]
labels = labels[indices]

train_images = images[:(len(labels) // 2)]
test_images = images[len(labels) // 2 + 1:]

train_labels = labels[:(len(labels) // 2)]
test_labels = labels[len(labels) // 2 + 1:]

# %%
np.unique(train_labels)
# Out:
# array([0, 1])

# %%
dataset = {}

dataset['train_input'] = torch.from_numpy(train_images).type(dtype)
dataset['train_label'] = torch.from_numpy(train_labels).type(torch.long)

dataset['test_input'] = torch.from_numpy(test_images).type(dtype)
dataset['test_label'] = torch.from_numpy(test_labels).type(torch.long)

# %%
model = KAN(width=[512, 2], grid=1, k=1, seed=2024, auto_save=False)

# %%
results = model.fit(dataset, opt="LBFGS", steps=5, loss_fn=torch.nn.CrossEntropyLoss(), lamb = 0.01);
# Out:
# | train_loss: 4.70e-01 | test_loss: 4.83e-01 | reg: 1.80e+01 | : 100%|█| 5/5 [00:15<00:00,  3.12s/it

# %%
def validate_model(model, X, y, device):
    correct = 0
    total = len(y)
    
    outputs = model(X)
    _, predicted = torch.max(outputs, 1)
    
    correct += (predicted == y).sum()
    accuracy = correct / total
    return accuracy

# %%
train_accuracy = validate_model(model, dataset["train_input"], dataset["train_label"] , device)
test_accuracy = validate_model(model, dataset["test_input"], dataset["test_label"] , device)
print(f"Train Accuracy: {train_accuracy}")
print(f"Test Accuracy: {test_accuracy}")
# Out:
# Train Accuracy: 0.9264000058174133
# Test Accuracy: 0.9151660799980164
